# %%
pip install panel hvplot geoviews
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/7c/b1/c27b294bc3bfc06d7721082568f53d076918a039864afc656d6d237fe08b/geoviews-1.10.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cartopy>=0.18.0 from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for shapely from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pyproj from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
# ...

# %%
import panel as pn
import geoviews as gv
import geoviews.tile_sources as gvts

# %%
df = read_csv('merged_data.csv')

# %%
# Die Weltkarte aus geoviews erstellen
world_map = gvts.CartoEco()

# Ein Panel-Widget erstellen
world_map_widget = pn.panel(world_map)

# Ein Panel-Text-Widget hinzufügen
title = pn.pane.Markdown("Interaktive Weltkarte", style={"font-size": "20px"})

# Ein Panel-Layout erstellen
layout = pn.Column(title, world_map_widget)

# Das Dashboard starten
layout.servable()
