# %%
import pycountry

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('merged_data.csv')

# %%
country_to_iso = {country.name: country.alpha_2 for country in pycountry.countries}
df['ISO_Code'] = df['Country'].map(country_to_iso)

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# ...

# %%
df['Country'].unique()
# Out:
# array(['Finland', 'Denmark', 'Iceland', 'Israel', 'Netherlands', 'Sweden',
#        'Norway', 'Switzerland', 'Luxembourg', 'New Zealand', 'Austria',
#        'Australia', 'Canada', 'Ireland', 'United States', 'Germany',
#        'Belgium', 'Czechia', 'United Kingdom', 'Lithuania', 'France',
#        'Slovenia', 'Costa Rica', 'Romania', 'Singapore',
#        'United Arab Emirates', 'Taiwan Province of China', 'Uruguay',
#        'Slovakia', 'Saudi Arabia', 'Estonia', 'Spain', 'Italy', 'Kosovo',
#        'Chile', 'Mexico', 'Malta', 'Panama', 'Poland', 'Nicaragua',
#        'Latvia', 'Bahrain', 'Guatemala', 'Kazakhstan', 'Serbia', 'Cyprus',
#        'Japan', 'Croatia', 'Brazil', 'El Salvador', 'Hungary',
#        'Argentina', 'Honduras', 'Uzbekistan', 'Malaysia', 'Portugal',
#        'South Korea', 'Greece', 'Mauritius', 'Thailand', 'Mongolia',
#        'Kyrgyzstan', 'Moldova', 'China', 'Vietnam', 'Paraguay',
#        'Montenegro', 'Jamaica', 'Bolivia', 'Russia',
# ...

# %%
df['ISO_Code'].isna().sum()
# Out:
# 190

# %%
nan_ISO = df['ISO_Code'].isnull() == True
df.loc[nan_ISO,:]
# Out:
#       Year                   Country                           Region  \
# 26    2023  Taiwan Province of China                              NaN
# 33    2023                    Kosovo       Central and Eastern Europe
# 56    2023               South Korea                     Eastern Asia
# 62    2023                   Moldova       Central and Eastern Europe
# 64    2023                   Vietnam                Southeastern Asia
# ...    ...                       ...                              ...
# 1329  2015          Congo (Kinshasa)               Sub-Saharan Africa
# 1348  2015       Congo (Brazzaville)               Sub-Saharan Africa
# 1355  2015                  Tanzania               Sub-Saharan Africa
# 1360  2015               Ivory Coast               Sub-Saharan Africa
# 1365  2015                     Syria  Middle East and Northern Africa
#
#       Happiness_Rank  Happiness  Explained_by_Trust  Explained_by_GDP  \
# ...

# %%
# Create a mapping of country names to ISO codes
country_to_iso_mapping = {}

# Iterate through the ISO countries and add name variations to the mapping
for country in pycountry.countries:
    # Check if the 'name' and 'official_name' attributes exist
    if hasattr(country, 'name') and hasattr(country, 'alpha_2'):
        country_to_iso_mapping[country.name] = country.alpha_2
    if hasattr(country, 'official_name') and hasattr(country, 'alpha_2'):
        country_to_iso_mapping[country.official_name] = country.alpha_2

# Handle specific variations or discrepancies

country_to_iso_mapping['Tanzania'] = 'TZ'
country_to_iso_mapping['Kosovo'] = 'XK'
country_to_iso_mapping['South Korea'] = 'KR'
country_to_iso_mapping['Vietnam'] = 'VN'
country_to_iso_mapping['Ivory Coast'] = 'CI'
country_to_iso_mapping['Czech Republic'] = 'CZ'
country_to_iso_mapping['Taiwan Province of China'] = 'TW'
country_to_iso_mapping['Moldova'] = 'MD'
country_to_iso_mapping['Bolivia'] = 'BO'
country_to_iso_mapping['Russia'] = 'RU'
country_to_iso_mapping['Hong Kong S.A.R. of China'] = 'HK'
country_to_iso_mapping['Venezuela'] = 'VE'
country_to_iso_mapping['Laos'] = 'LA'
country_to_iso_mapping['State of Palestine'] = 'PS'
country_to_iso_mapping['Iran'] = 'IR'
country_to_iso_mapping['Turkiye'] = 'TR'
country_to_iso_mapping['Luxembourg*'] = 'LU'
country_to_iso_mapping['Guatemala*'] = 'GT'
country_to_iso_mapping['Kuwait*'] = 'KW'
country_to_iso_mapping['Belarus*'] = 'BY'
country_to_iso_mapping['Turkmenistan*'] = 'TM'
country_to_iso_mapping['North Cyprus*'] = 'CY'
country_to_iso_mapping['Libya*'] = 'LY'
country_to_iso_mapping['Azerbaijan*'] = 'AZ'
country_to_iso_mapping['Gambia*'] = 'GM'
country_to_iso_mapping['Liberia*'] = 'LR'
country_to_iso_mapping['Niger*'] = 'NE'
country_to_iso_mapping['Comoros*'] = 'KM'
country_to_iso_mapping['Palestinian Territories*'] = 'PS'
country_to_iso_mapping['Eswatini, Kingdom of*'] = 'SZ'
country_to_iso_mapping['Madagascar*'] = 'MG'
country_to_iso_mapping['Chad*'] = 'TD'
country_to_iso_mapping['Yemen*'] = 'YE'
country_to_iso_mapping['Mauritania*'] = 'MR'
country_to_iso_mapping['North Cyprus'] = 'CY'  # no differentiationg within Cyprus
country_to_iso_mapping['Palestinian Territories'] = 'PS' 
country_to_iso_mapping['Swaziland'] = 'SZ'  
country_to_iso_mapping['Macedonia'] = 'MK' 
country_to_iso_mapping['Taiwan'] = 'TW'  
country_to_iso_mapping['Trinidad & Tobago'] = 'TT' 
country_to_iso_mapping['Northern Cyprus'] = 'CY'  # no differentiationg within Cyprus
country_to_iso_mapping['Syria'] = 'SY'  
country_to_iso_mapping['Hong Kong S.A.R., China'] = 'HK' 
country_to_iso_mapping['Somaliland Region'] = 'SOX'  # adding an X to Somalia ISO code just to avoid different rows with different data for the same year with the same ISO code SO
country_to_iso_mapping['Somaliland region'] = 'SOX'  # adding an X to Somalia ISO code just to avoid different rows with different data for the same year with the same ISO code SO



# Handle variations with extra info in brackets
country_to_iso_mapping['Congo (Kinshasa)'] = 'CD'
country_to_iso_mapping['Congo (Brazzaville)'] = 'CG'

# Handle variations with an asterisk
country_to_iso_mapping['Lesotho*'] = 'LS'
country_to_iso_mapping['Botswana*'] = 'BW'
country_to_iso_mapping['Rwanda*'] = 'RW'

# Use the mapping to fill in missing ISO codes
df['ISO_Code'] = df['Country'].map(country_to_iso_mapping)

# Check the DataFrame for missing ISO codes
missing_iso_codes = df[df['ISO_Code'].isna()]

# %%
missing_iso_codes
# Out:
#      Year Country Region  Happiness_Rank  Happiness  Explained_by_Trust  \
# 283  2022      xx    NaN             147        NaN                 NaN
#
#      Explained_by_GDP  Explained_by_Freedom  Explained_by_Generosity  \
# 283               NaN                   NaN                      NaN
#
#      Explained_by_Health  Explained_by_Social_support  Dystopia_Residual  \
# 283                  NaN                          NaN                NaN
#
#     ISO_Code
# 283      NaN

# %%
unique_country_count = df['Country'].nunique()
print("Number of unique country entries:", unique_country_count)
# Out:
# Number of unique country entries: 198

# %%
unique_ISO_count=df['ISO_Code'].nunique()
print("Number of unique ISO entries:", unique_ISO_count)
# Out:
# Number of unique ISO entries: 164

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'Middle East and Northern Africa',
#        'Australia and New Zealand', 'North America', nan,
#        'Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Eastern Asia', 'Sub-Saharan Africa',
#        'Southern Asia'], dtype=object)

# %%
unique_Region_count=df['Region'].nunique()
print("Number of unique Region entries:", unique_Region_count)
# Out:
# Number of unique Region entries: 10

# %%
df['Region'].isna().sum()
# Out:
# 67

# %%
region_mapping = {
    'Western Europe': 'WE',
    'Middle East and Northern Africa': 'MENAF',
    'Australia and New Zealand': 'ANZ',
    'North America': 'NAM',
    'Central and Eastern Europe': 'CEE', 
    'Latin America and Caribbean': 'LAC',
    'Southeastern Asia': 'SEAS', 
    'Eastern Asia': 'EAS', 
    'Sub-Saharan Africa':'SSAF',
    'Southern Asia':'SAS',
    'Commonwealth of Independent States':'CIS'
}

# %%
df.head(20)
# Out:
#     Year         Country                           Region  Happiness_Rank  \
# 0   2023         Finland                   Western Europe               1
# 1   2023         Denmark                   Western Europe               2
# 2   2023         Iceland                   Western Europe               3
# 3   2023          Israel  Middle East and Northern Africa               4
# 4   2023     Netherlands                   Western Europe               5
# 5   2023          Sweden                   Western Europe               6
# 6   2023          Norway                   Western Europe               7
# 7   2023     Switzerland                   Western Europe               8
# 8   2023      Luxembourg                   Western Europe               9
# 9   2023     New Zealand        Australia and New Zealand              10
# 10  2023         Austria                   Western Europe              11
# 11  2023       Australia        Australia and New Zealand              12
# ...

# %%
# Create a mapping between ISO country codes and regions
iso_to_region_mapping = {
    'CZ': 'Central and Eastern Europe',
    'TW': 'Eastern Asia',
    'HK': 'Eastern Asia',
    'MK': 'Central and Eastern Europe', 
    'PS': 'Middle East and Northern Africa', 
    'NA': 'Sub-Saharan Africa', 
    'TR': 'Middle East and Northern Africa',
    'GM': 'Sub-Saharan Africa',
    'LU': 'Western Europe', 
    'GT': 'Latin America and Caribbean', 
    'KW': 'Middle East and Northern Africa',
    'BY': 'Central and Eastern Europe', 
    'TM': 'Commonwealth of Independent States', #after discussing with Laura, I do add this Region to our data for 12 countries. 
                                                #Reason: I do not see Russia, Kazachstan, Turkmenistan etc. as Central and Eastern Europe Region ("faulty" Region in .csv earlier years, 
                                                #but these 12 countries are listed as commonwealth... region later on in the original csv files)
    'CY': 'Western Europe', 
    'LY': 'Middle East and Northern Africa', 
    'AZ': 'Commonwealth of Independent States', 
    'LR': 'Sub-Saharan Africa', 
    'CG': 'Sub-Saharan Africa', 
    'NE': 'Sub-Saharan Africa', 
    'KM': 'Sub-Saharan Africa', 
    'SZ': 'Sub-Saharan Africa', 
    'MG': 'Sub-Saharan Africa',
    'TD': 'Sub-Saharan Africa', 
    'YE': 'Middle East and Northern Africa', 
    'MR': 'Sub-Saharan Africa', 
    'LS': 'Sub-Saharan Africa', 
    'BW': 'Sub-Saharan Africa', 
    'RW': 'Sub-Saharan Africa', 
    'MV': 'Sub-Saharan Africa', 
    'SS': 'Sub-Saharan Africa', 
    'TT': 'Latin America and Caribbean', 
    'SO': 'Sub-Saharan Africa',
    'BZ': 'Latin America and Caribbean'
    
}

# Fill the "Region" column using iso_to_region_mapping
df['Region'] = df['ISO_Code'].map(iso_to_region_mapping)

# Check the DataFrame for any remaining missing values
missing_regions = df[df['Region'].isna()]

# %%
missing_Region_codes['ISO_Code'].nunique()
# Out:
# 131

# %%
df['Region'].isna().sum()
# Out:
# 1108
