# %%
import pandas as pd
import panel as pn
import numpy as np
import hvplot.pandas
import folium
from panel.interact import interact
pn.extension('tabulator')
pn.extension
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# panel.config.panel_extension

# %%
df = pd.read_csv('Data/merged_data.csv', sep=',')
#df.head(1)

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('Data/merged_data.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2015, end=2023, step=1, value=2015)
year_slider
# Out:
# IntSlider(end=2023, name='Year slider', start=2015, value=2015)

# %%
idf.head(2)
# Out:
# <div id='9b734e65-5a14-4832-86c0-bd2e868a36cf'>
#   <div id="c7c20566-0b8a-4056-bc0b-9dbfa1a336d2" data-root-id="9b734e65-5a14-4832-86c0-bd2e868a36cf" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b925ba39-e3cd-4ca1-ad0e-5d7e5b01995d":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"9b734e65-5a14-4832-86c0-bd2e868a36cf","attributes":{"name":"Row00907","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"f9d7bf6b-3346-41f3-be4c-44b53b54041a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f1c97e90-a2c6-4cf7-b47c-bca70b64ab37","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7673d2c2-34a5-4001-90e0-bbd3ec30f838","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5bffd2f3-3caf-4a0d-97b8-948a947f89b9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7d254b6d-9bc6-4cea-975b-e9b05b233975","attributes":{"name":"Column00892","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"f9d7bf6b-3346-41f3-be4c-44b53b54041a"},{"id":"f1c97e90-a2c6-4cf7-b47c-bca70b64ab37"},{"id":"7673d2c2-34a5-4001-90e0-bbd3ec30f838"},{"id":"5bffd2f3-3caf-4a0d-97b8-948a947f89b9"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"12a51212-4f17-482d-935e-8834080751c5","attributes":{"name":"Column00904","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"f9d7bf6b-3346-41f3-be4c-44b53b54041a"},{"id":"f1c97e90-a2c6-4cf7-b47c-bca70b64ab37"},{"id":"7673d2c2-34a5-4001-90e0-bbd3ec30f838"},{"id":"5bffd2f3-3caf-4a0d-97b8-948a947f89b9"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"d336f4f3-609b-42d5-8929-ae0e86119f51","attributes":{"name":"Row00901","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"f9d7bf6b-3346-41f3-be4c-44b53b54041a"},{"id":"f1c97e90-a2c6-4cf7-b47c-bca70b64ab37"},{"id":"7673d2c2-34a5-4001-90e0-bbd3ec30f838"},{"id":"5bffd2f3-3caf-4a0d-97b8-948a947f89b9"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"bf6073b7-c49a-4bff-a9fc-3ebd89a688ca","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"f9d7bf6b-3346-41f3-be4c-44b53b54041a"},{"type":"object","name":"ImportedStyleSheet","id":"62ce6661-3654-404a-9f5f-4483f0a1f34b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"7673d2c2-34a5-4001-90e0-bbd3ec30f838"},{"id":"5bffd2f3-3caf-4a0d-97b8-948a947f89b9"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Region&lt;/th&gt;\n      &lt;th&gt;Happiness_Rank&lt;/th&gt;\n      &lt;th&gt;Happiness&lt;/th&gt;\n      &lt;th&gt;Explained_by_Trust&lt;/th&gt;\n      &lt;th&gt;Explained_by_GDP&lt;/th&gt;\n      &lt;th&gt;Explained_by_Freedom&lt;/th&gt;\n      &lt;th&gt;Explained_by_Generosity&lt;/th&gt;\n      &lt;th&gt;Explained_by_Health&lt;/th&gt;\n      ...

# %%
country_list = list(df['Country'].unique())

# %%
country_list.sort()

# %%
# create widget
select = pn.widgets.Select(name='Select Country', options=country_list)

# %%
country_pipeline_1 = (
    idf[(idf['Country']==select)&(idf['Year']<= year_slider)]
    .groupby(['Year'])[['Happiness_Rank','Happiness','Explained_by_GDP','Explained_by_Health']].max()
    #.to_frame()
    .reset_index()
    .sort_values(by=['Year'])  
    .reset_index(drop=True)
) 
country_pipeline_2 = (
    idf[(idf['Year']<=year_slider)&(idf['Happiness'])]
     .groupby('Year')['Happiness'].mean()
)
country_year_pipeline = (country_pipeline_1, country_pipeline_2)

# %%
#country_year_pipeline[0]

# %%
#country_year_pipeline.hvplot.table(width=500)

# %%
#country_stats=pn.panel(country_year_pipeline[0].hvplot.table(width=500,
#                                                          title="Data Table") +
#                       country_year_pipeline[0].hvplot.line(x='Year',
#                                                         y='Happiness',
#                                                         cmap='Dark2',
#                                                         rot=0, 
#                                                         width=500,
#                                                         height=300,
#                                                         title="Happiness Changes over Time",
#                                                         )
#                                                         )#

# %%
#country_stats

# %%
global_mean = df.groupby('Year')['Happiness'].mean()

# %%
#global_mean.plot()

# %%
average_happiness_plot = country_year_pipeline[1].hvplot.line(x='Year',
                                                             y='Happiness',
                                                             line_dash='dashed',
                                                             line_width=1.25,
                                                             line_color='black',
                                                             title="Average Happiness over Time",
                                                             width=500,
                                                             height=300,
                                                             legend=False
                                                             )                                                             


happiness_changes_plot = country_year_pipeline[0].hvplot.line(x='Year',
                                                              y='Happiness',
                                                              line_width=2.5,
                                                              line_color='green',
                                                              rot=0,
                                                              width=500,
                                                              height=300,
                                                              title="Happiness Change over Time vs. Global Happiness Mean",
                                                              legend=False,
                                                              grid=True,
                                                              hover_cols='Happiness_Rank'
                                                              )
country_stats_test = pn.panel(country_year_pipeline[0].hvplot.table(width=500, title="Data Table")+
                              (happiness_changes_plot * average_happiness_plot)
                         )

country_stats_test
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# Interactive(Interactive)
