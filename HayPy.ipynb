# %%
import pandas as pd
import plotly.graph_objects as go

df_15 = pd.read_csv("2015.csv")
df_15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_16 = pd.read_csv("2016.csv")
df_16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_17 = pd.read_csv("2017.csv")
df_17.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_18 = pd.read_csv("2018.csv")
df_18 = df_18.rename(columns= {"Country or region" : "Country"})
df_18.head()
df_18.to_csv("2018.csv", index=False)

# %%
df_19 = pd.read_csv("2019.csv")
df_19 = df_19.rename(columns= {"Country or region" : "Country"})
df_19.head()
df_19.to_csv("2019.csv", index=False)

# %%
df_20 = pd.read_csv("2020.csv")
df_20 = df_20.rename(columns= {"Country name" : "Country"})
df_20.head()
df_20.to_csv("2020.csv", index=False)

# %%
df_21 = pd.read_csv("2021.csv")
df_21 = df_21.rename(columns= {"Country name" : "Country"})
df_21.head()
# Out:
#        Country Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df_22 = pd.read_csv("2022.csv")
df_22.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
df_23 = pd.read_csv("2023.csv")
df_23 = df_23.rename(columns= {"Country name" : "Country"})
df_23.head()
# Out:
#        Country  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
df = pd.read_csv("time_series_covid_19_confirmed.csv")

df = df.rename(columns= {"Country/Region" : "Country"})
df.head()
# Out:
#   Province/State      Country       Lat       Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN  Afghanistan  33.93911  67.709953        0        0        0
# 1            NaN      Albania  41.15330  20.168300        0        0        0
# 2            NaN      Algeria  28.03390   1.659600        0        0        0
# 3            NaN      Andorra  42.50630   1.521800        0        0        0
# 4            NaN       Angola -11.20270  17.873900        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  5/23/21  \
# 0        0        0        0  ...    64575    65080    65486    65728
# 1        0        0        0  ...   132118   132153   132176   132209
# 2        0        0        0  ...   126156   126434   126651   126860
# 3        0        0        0  ...    13569    13569    13569    13569
# 4        0        0        0  ...    31661    31909    32149    32441
#
#    5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
selected_columns = df[['Long', 'Lat', 'Country']]

# Erstellen Sie ein neues DataFrame, das nur die ausgewählten Spalten enthält
new_df = pd.DataFrame(selected_columns)
new_df.head()
new_df.to_csv("Lage_Länder.csv", index=False)

# %%
print(df_18['Country'].unique)
print(new_df['Country'].unique)
# Out:
# <bound method Series.unique of 0                       Finland
# 1                        Norway
# 2                       Denmark
# 3                       Iceland
# 4                   Switzerland
#                  ...
# 151                       Yemen
# 152                    Tanzania
# 153                 South Sudan
# 154    Central African Republic
# 155                     Burundi
# Name: Country, Length: 156, dtype: object>
# <bound method Series.unique of 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
#               ...
# 271               Vietnam
# 272    West Bank and Gaza
# 273                 Yemen
# 274                Zambia
# 275              Zimbabwe
# Name: Country, Length: 276, dtype: object>

# %%
# Finden Sie die gemeinsamen Werte zwischen Spalte_A von df1 und Spalte_B von df2
gemeinsame_werte = pd.Series(list(set(df_18['Country']) & set(new_df['Country'])))
gemeinsame_werte =gemeinsame_werte.sort_values(ascending=True)
# Finden Sie die Werte, die in Spalte_A von df1, aber nicht in Spalte_B von df2 enthalten sind
werte_nur_in_df_18 = df_18[~df_18['Country'].isin(new_df['Country'])]

# Finden Sie die Werte, die in Spalte_B von df2, aber nicht in Spalte_A von df1 enthalten sind
werte_nur_in_new_df = new_df[~new_df['Country'].isin(df_18['Country'])]

# Sortieren Sie die DataFrames ohne inplace=True
werte_nur_in_df_18 = werte_nur_in_df_18.sort_values(by='Country', ascending=True)
werte_nur_in_new_df = werte_nur_in_new_df.sort_values(by='Country', ascending=True)

# Ausgabe der Ergebnisse
print("Gemeinsame Werte:")
print("________________________")
print(gemeinsame_werte.tolist())
print("________________________")
print("Werte nur in df_18:")
print("________________________")
print(werte_nur_in_df_18['Country'].tolist())
print("________________________")
print("Werte nur in new_df:")
print("________________________")
print(werte_nur_in_new_df['Country'].tolist())
# Out:
# Gemeinsame Werte:
# ________________________
# ...

# %%
capital_coordinates = {
    'Czech Republic': {'Lat': 50.0755, 'Long': 14.4378}, 
    'Hong Kong': {'Lat': 22.3193, 'Long': 114.1694},
    'Ivory Coast': {'Lat': 6.5244, 'Long': -7.5100},
    'Macedonia': {'Lat': 41.9965, 'Long': 21.4314},
    'Myanmar': {'Lat': 19.7450, 'Long': 96.1297},
    'Northern Cyprus': {'Lat': 35.1864, 'Long': 33.3823},
    'Palestinian Territories': {'Lat': 31.7783, 'Long': 35.2066},
    'South Korea': {'Lat': 37.5665, 'Long': 126.9780},
    'Taiwan': {'Lat': 25.0320, 'Long': 121.5654},
    'Trinidad & Tobago': {'Lat': 10.6506, 'Long': -61.5137},
    'Turkmenistan': {'Lat': 37.9601, 'Long': 58.3253},
    'United States': {'Lat': 38.8951, 'Long': -77.0364}
}

for country, coordinates in capital_coordinates.items():
    if country not in new_df['Country'].values:
        new_df = new_df.append({'Country': country, 'Lat': coordinates['Lat'], 'Long': coordinates['Long']}, ignore_index=True)
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_15268\3687596955.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Country': country, 'Lat': coordinates['Lat'], 'Long': coordinates['Long']}, ignore_index=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15268\3687596955.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Country': country, 'Lat': coordinates['Lat'], 'Long': coordinates['Long']}, ignore_index=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15268\3687596955.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Country': country, 'Lat': coordinates['Lat'], 'Long': coordinates['Long']}, ignore_index=True)
# ...

# %%
# Finden Sie die gemeinsamen Werte zwischen Spalte_A von df1 und Spalte_B von df2
gemeinsame_werte = pd.Series(list(set(df_18['Country']) & set(new_df['Country'])))
gemeinsame_werte =gemeinsame_werte.sort_values(ascending=True)
# Finden Sie die Werte, die in Spalte_A von df1, aber nicht in Spalte_B von df2 enthalten sind
werte_nur_in_df_18 = df_18[~df_18['Country'].isin(new_df['Country'])]

# Finden Sie die Werte, die in Spalte_B von df2, aber nicht in Spalte_A von df1 enthalten sind
werte_nur_in_new_df = new_df[~new_df['Country'].isin(df_18['Country'])]

# Sortieren Sie die DataFrames ohne inplace=True
werte_nur_in_df_18 = werte_nur_in_df_18.sort_values(by='Country', ascending=True)
werte_nur_in_new_df = werte_nur_in_new_df.sort_values(by='Country', ascending=True)

# Ausgabe der Ergebnisse
print("Gemeinsame Werte:")
print("________________________")
print(gemeinsame_werte.tolist())
print("________________________")
print("Werte nur in df_18:")
print("________________________")
print(werte_nur_in_df_18['Country'].tolist())
print("________________________")
print("Werte nur in new_df:")
print("________________________")
print(werte_nur_in_new_df['Country'].tolist())
# Out:
# Gemeinsame Werte:
# ________________________
# ...

# %%
combined_df = df_18.merge(new_df, on='Country', how='inner')

# %%
combined_df['text'] = combined_df['Country'] + " " + combined_df["Score"].astype(str)
fig = go.Figure(data = go.Scattergeo(
    lon = combined_df["Long"],
    lat = combined_df["Lat"],
    text = combined_df["text"],
    mode = "markers",
    marker = dict(
        size = 12,
        opacity = 0.8,
        reversescale = True,
        autocolorscale = True,
        symbol = 'square',
        line = dict(
            width = 1,
            color = 'rgba(102, 102, 102)'
        ),
        cmin = 0,
        color = combined_df['Score'],
        cmax = combined_df['Score'].max(),
        colorbar_title = "Happiness 2018"
    )
))

fig.update_layout(
    title = "Happiness 2018",
    geo = dict(
        scope = "world",
        showland = True,
    )
)

fig.write_html('first_figure.html', auto_open=True)

# %%
total_list = df.groupby('Country')['4/13/20'].sum().tolist()

country_list = df["Country"].tolist()
country_set = set(country_list)
country_list = list(country_set)
country_list.sort()

new_df = pd.DataFrame(list(zip(country_list, total_list)), 
               columns =['Country', 'Total_Cases'])

# %%
colors = ["#F9F9F5", "#FAFAE6", "#FCFCCB", "#FCFCAE",  "#FCF1AE", "#FCEA7D", "#FCD97D",
          "#FCCE7D", "#FCC07D", "#FEB562", "#F9A648",  "#F98E48", "#FD8739", "#FE7519",
          "#FE5E19", "#FA520A", "#FA2B0A", "#9B1803",  "#861604", "#651104", "#570303",]


fig = go.Figure(data=go.Choropleth(
    locationmode = "country names",
    locations = df_18['Country'],
    z = df_18['Total_Cases'],
    text = df_18['Total_Cases'],
    colorscale = colors,
    autocolorscale=False,
    reversescale=False,
    colorbar_title = 'Happiness 2018-2020',
))

fig.update_layout(
    title_text='Reported Covid-19 Cases',
    geo=dict(
        showcoastlines=True,
    ),
)

fig.write_html('Happiness 2018-2020', auto_open=True)

# %%
import pandas as pd
import plotly.graph_objects as go

def generate_happiness_map():
    year = input("Geben Sie das Jahr ein (z.B. 2018): ")
    
    if year == "2018":
        # Hier sollte DataFrame "combined_df" bereits definiert sein
        combined_df['text'] = combined_df['Country'] + " " + combined_df["Score"].astype(str)
        
        fig = go.Figure(data = go.Scattergeo(
            lon = combined_df["Long"],
            lat = combined_df["Lat"],
            text = combined_df["text"],
            mode = "markers",
            marker = dict(
                size = 12,
                opacity = 0.8,
                reversescale = True,
                autocolorscale = True,
                symbol = 'square',
                line = dict(
                    width = 1,
                    color = 'rgba(102, 102, 102)'
                ),
                cmin = 0,
                color = combined_df['Score'],
                cmax = combined_df['Score'].max(),
                colorbar_title = "Happiness 2018"
            )
        ))

        fig.update_layout(
            title = "Happiness 2018",
            geo = dict(
                scope = "world",
                showland = True,
            )
        )

        fig.write_html('first_figure.html', auto_open=True)
    else:
        print("Das Jahr", year, "wird nicht unterstützt.")

# Rufen Sie die Funktion auf
generate_happiness_map()
# Out:
# Geben Sie das Jahr ein (z.B. 2018): 2018

# %%
import pandas as pd

# Erstellen Sie eine Liste von DataFrames
dataframes = [df_18, df_19, df_20, df_21]  # Fügen Sie hier alle gewünschten DataFrames hinzu

# Initialisieren leere Listen für Ergebnisse
gemeinsame_werte_list = []
werte_nur_in_dataframes = []

# Spalte_B von df2 (new_df) festlegen
spalte_B = new_df['Country']

for year, dataframe in zip(range(2018, 2022), dataframes):
    # Finden Sie gemeinsame Werte
    gemeinsame_werte = pd.Series(list(set(dataframe['Country']) & set(spalte_B)))
    gemeinsame_werte = gemeinsame_werte.sort_values(ascending=True)
    gemeinsame_werte_list.append(gemeinsame_werte.tolist())

    # Finden Sie Werte nur in Spalte_A von df1
    werte_nur_in_dataframes.append(dataframe[~dataframe['Country'].isin(spalte_B)]['Country'].tolist())

# Ausgabe der Ergebnisse
for year, gemeinsame_werte, werte_nur_in_dataframe in zip(range(2018, 2022), gemeinsame_werte_list, werte_nur_in_dataframes):
    print(f"Gemeinsame Werte für {year}:")
    print("________________________")
    print(gemeinsame_werte)
    print("________________________")
    print(f"Werte nur in df_{year}:")
    print("________________________")
    print(werte_nur_in_dataframe)
    print("________________________")
