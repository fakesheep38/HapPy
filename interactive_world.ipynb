# %%
#import geoviews as gv
#import geoviews.tile_sources as gvts

# %%
import pandas as pd
import numpy as np
import hvplot.pandas
import panel as pn
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('merged_data.csv')

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# 0                    0.126                0.535                        1.585
# 1                    0.208                0.537                        1.548
# 2                    0.250                0.559                        1.620
# 3                    0.124                0.577                        1.521
# 4                    0.251                0.545                        1.488
#
#    Dystopia_Residual
# 0              2.363
# 1              2.084
# 2              2.250
# 3              2.691
# 4              2.110

# %%
value_to_delete = 'xx'
df = df[df['Country'] != value_to_delete]

# %%
#mittelwerte = df.mean()
#df = df.append(mittelwerte, ignore_index=True) 
#Werte für World sind noch nicht berechnet

# %%
df = df.dropna()

# %%
country_to_continent = {
    'Finland': 'Europe',
    'Denmark': 'Europe',
    'Iceland': 'Europe',
    'Israel': 'Asia',
    'Netherlands': 'Europe',
    'Sweden': 'Europe',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Luxembourg': 'Europe',
    'New Zealand': 'Oceania',
    'Austria': 'Europe',
    'Australia': 'Oceania',
    'Canada': 'North America',
    'Ireland': 'Europe',
    'United States': 'North America',
    'Germany': 'Europe',
    'Belgium': 'Europe',
    'Czechia': 'Europe',
    'United Kingdom': 'Europe',
    'Lithuania': 'Europe',
    'France': 'Europe',
    'Slovenia': 'Europe',
    'Costa Rica': 'North America',
    'Romania': 'Europe',
    'Singapore': 'Asia',
    'United Arab Emirates': 'Asia',
    'Taiwan Province of China': 'Asia',
    'Uruguay': 'South America',
    'Slovakia': 'Europe',
    'Saudi Arabia': 'Asia',
    'Estonia': 'Europe',
    'Spain': 'Europe',
    'Italy': 'Europe',
    'Kosovo': 'Europe',
    'Chile': 'South America',
    'Mexico': 'North America',
    'Malta': 'Europe',
    'Panama': 'North America',
    'Poland': 'Europe',
    'Nicaragua': 'North America',
    'Latvia': 'Europe',
    'Bahrain': 'Asia',
    'Guatemala': 'North America',
    'Kazakhstan': 'Asia',
    'Serbia': 'Europe',
    'Cyprus': 'Europe',
    'Japan': 'Asia',
    'Croatia': 'Europe',
    'Brazil': 'South America',
    'El Salvador': 'North America',
    'Hungary': 'Europe',
    'Argentina': 'South America',
    'Honduras': 'North America',
    'Uzbekistan': 'Asia',
    'Malaysia': 'Asia',
    'Portugal': 'Europe',
    'South Korea': 'Asia',
    'Greece': 'Europe',
    'Mauritius': 'Africa',
    'Thailand': 'Asia',
    'Mongolia': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Moldova': 'Europe',
    'China': 'Asia',
    'Vietnam': 'Asia',
    'Paraguay': 'South America',
    'Montenegro': 'Europe',
    'Jamaica': 'North America',
    'Bolivia': 'South America',
    'Russia': 'Europe',
    'Bosnia and Herzegovina': 'Europe',
    'Colombia': 'South America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Bulgaria': 'Europe',
    'Nepal': 'Asia',
    'Armenia': 'Asia',
    'Tajikistan': 'Asia',
    'Algeria': 'Africa',
    'Hong Kong S.A.R. of China': 'Asia',
    'Albania': 'Europe',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Congo (Brazzaville)': 'Africa',
    'North Macedonia': 'Europe',
    'Venezuela': 'South America',
    'Laos': 'Asia',
    'Georgia': 'Asia',
    'Guinea': 'Africa',
    'Ukraine': 'Europe',
    'Ivory Coast': 'Africa',
    'Gabon': 'Africa',
    'Nigeria': 'Africa',
    'Cameroon': 'Africa',
    'Mozambique': 'Africa',
    'Iraq': 'Asia',
    'State of Palestine': 'Asia',
    'Morocco': 'Africa',
    'Iran': 'Asia',
    'Senegal': 'Africa',
    'Mauritania': 'Africa',
    'Burkina Faso': 'Africa',
    'Namibia': 'Africa',
    'Turkiye': 'Asia',
    'Ghana': 'Africa',
    'Pakistan': 'Asia',
    'Niger': 'Africa',
    'Tunisia': 'Africa',
    'Kenya': 'Africa',
    'Sri Lanka': 'Asia',
    'Uganda': 'Africa',
    'Chad': 'Africa',
    'Cambodia': 'Asia',
    'Benin': 'Africa',
    'Myanmar': 'Asia',
    'Bangladesh': 'Asia',
    'Gambia': 'Africa',
    'Mali': 'Africa',
    'Egypt': 'Africa',
    'Togo': 'Africa',
    'Jordan': 'Asia',
    'Ethiopia': 'Africa',
    'Liberia': 'Africa',
    'India': 'Asia',
    'Madagascar': 'Africa',
    'Zambia': 'Africa',
    'Tanzania': 'Africa',
    'Comoros': 'Africa',
    'Malawi': 'Africa',
    'Botswana': 'Africa',
    'Congo (Kinshasa)': 'Africa',
    'Zimbabwe': 'Africa',
    'Sierra Leone': 'Africa',
    'Lebanon': 'Asia',
    'Afghanistan': 'Asia',
    'Luxembourg*': 'Europe',
    'Guatemala*': 'North America',
    'Kuwait*': 'Asia',
    'Belarus*': 'Europe',
    'Turkmenistan*': 'Asia',
    'North Cyprus*': 'Europe',
    'Libya*': 'Africa',
    'Azerbaijan*': 'Asia',
    'Gambia*': 'Africa',
    'Liberia*': 'Africa',
    'Congo': 'Africa',
    'Niger*': 'Africa',
    'Turkey': 'Asia',
    'Comoros*': 'Africa',
    'Palestinian Territories*': 'Asia',
    'Eswatini, Kingdom of*': 'Africa',
    'Madagascar*': 'Africa',
    'Chad*': 'Africa',
    'Yemen*': 'Asia',
    'Mauritania*': 'Africa',
    'Lesotho*': 'Africa',
    'Botswana*': 'Africa',
    'Rwanda*': 'Africa',
    'xx': 'Unknown',
    'Czech Republic': 'Europe',
    'Kuwait': 'Asia',
    'North Cyprus': 'Europe',
    'Belarus': 'Europe',
    'Libya': 'Africa',
    'Maldives': 'Asia',
    'Azerbaijan': 'Asia',
    'Turkmenistan': 'Asia',
    'Palestinian Territories': 'Asia',
    'Swaziland': 'Africa',
    'Burundi': 'Africa',
    'Yemen': 'Asia',
    'Haiti': 'North America',
    'Lesotho': 'Africa',
    'Rwanda': 'Africa',
    'Trinidad and Tobago': 'North America',
    'Macedonia': 'Europe',
    'Central African Republic': 'Africa',
    'South Sudan': 'Africa',
    'Taiwan': 'Asia',
    'Qatar': 'Asia',
    'Trinidad & Tobago': 'North America',
    'Northern Cyprus': 'Europe',
    'Hong Kong': 'Asia',
    'Bhutan': 'Asia',
    'Somalia': 'Africa',
    'Syria': 'Asia',
    'Belize': 'North America',
    'Sudan': 'Africa',
    'Angola': 'Africa',
    'Hong Kong S.A.R., China': 'Asia',
    'Puerto Rico': 'North America',
    'Suriname': 'South America',
    'Somaliland Region': 'Africa',
    'Oman': 'Asia',
    'Somaliland region': 'Africa',
    'Djibouti': 'Africa',
}

# %%
df['Kontinent'] = df['Country'].map(country_to_continent)

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2015, end=2024, step=1, value=2017)
year_slider
# Out:
# IntSlider(end=2024, name='Year slider', start=2015, value=2017)

# %%
# Radio buttons for Happiness
yaxis_Happy = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness', 'Happiness_Rank',],
    button_type='success'
)

# %%
display(yaxis_Happy)
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Happiness', ...], value='Happiness')

# %%
continents = [ 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']#'World',

happy_pipeline = (
    idf[
        (idf.Year >= year_slider) &
        (idf.Kontinent.isin(continents))
    ]
    .groupby(['Kontinent', 'Year'])[yaxis_Happy].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happy_pipeline
# Out:
# <div id='71355c39-895d-45db-838d-12eb3ed3e56b'>
#   <div id="cd0f2614-2212-4c7b-b185-080b1a938c97" data-root-id="71355c39-895d-45db-838d-12eb3ed3e56b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"469e2f57-3ed1-4e09-a2c2-ec9331d9befa":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"71355c39-895d-45db-838d-12eb3ed3e56b","attributes":{"name":"Row04718","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0e558a4b-7410-4d46-8859-cb0e00572d84","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"01a3a25e-e69e-4703-97aa-7ed3980f4bc3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"0ee21585-c734-4858-aec5-770331b89406","attributes":{"name":"Column04715","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e558a4b-7410-4d46-8859-cb0e00572d84"},{"id":"01a3a25e-e69e-4703-97aa-7ed3980f4bc3"},{"id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff"},{"id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"c36bbc82-4733-4121-9c0c-398d30009918","attributes":{"name":"Column04685","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e558a4b-7410-4d46-8859-cb0e00572d84"},{"id":"01a3a25e-e69e-4703-97aa-7ed3980f4bc3"},{"id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff"},{"id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"28ef12e6-b50c-455a-aacf-9917699a9520","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e558a4b-7410-4d46-8859-cb0e00572d84"},{"id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff"},{"id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"2126665b-2ed0-41bf-b077-5f3b8a1ffda4","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e558a4b-7410-4d46-8859-cb0e00572d84"},{"type":"object","name":"ImportedStyleSheet","id":"afb3d3a9-c625-49a6-b2de-eb7913b5f4bd","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff"},{"id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81"}],"margin":[5,10],"align":"start","labels":["Happiness","Happiness_Rank"],"active":0}}]}},{"type":"object","name":"Column","id":"0307f8a8-c0ae-4247-96f5-0ecd295d7ec7","attributes":{"name":"Column04700","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e558a4b-7410-4d46-8859-cb0e00572d84"},{"id":"01a3a25e-e69e-4703-97aa-7ed3980f4bc3"},{"id":"77b99051-ec5c-4bb0-8da8-c70be26bf3ff"},{"id":"4218489b-d1f5-499f-bf31-5d42bdf1cd81"}],"margin":0,"align":"start","children":[{"typ ...

# %%
happy_plot = happy_pipeline.hvplot(x = 'Year', by='Kontinent', y=yaxis_Happy,line_width=2, title="Happyness by Continent")

# %%
happy_plot
# Out:
# <div id='791d235e-d4c2-42e9-851d-7a9e639fbfa5'>
#   <div id="eaa70ab5-8c82-4b88-a47b-10b3f2a1310f" data-root-id="791d235e-d4c2-42e9-851d-7a9e639fbfa5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"
"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"60b057ca-4266-4a24-8244-c6eebd161193","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e3adf9ce-6453-4ad6-9b69-41f0efdc738b"},{"type":"object","name":"ImportedStyleSheet","id":"bc8d497a-d34e-45af-9448-2123ed27cf54","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/dataframe.css"}},{"id":"62a54bd6-937d-4e95-bcec-2415d86e7426"},{"id":"8a132ad5-286c-4a04-8ab5-785888675db3"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=& ...

# %%
happy_vs_GDP_scatterplot = happy_vs_GDP_scatterplot_pipeline.hvplot(x='Explained_by_GDP', 
                                                                y='Happiness', 
                                                                by='Kontinent', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)

# %%
happy_vs_GDP_scatterplot
# Out:
# <div id='e60f2a2d-d520-4806-a004-bac21eddfa96'>
#   <div id="f91cc679-d30d-4214-811f-36403aace5ab" data-root-id="e60f2a2d-d520-4806-a004-bac21eddfa96" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"93711766-6e3d-4e91-926b-b169d43d2249":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"e60f2a2d-d520-4806-a004-bac21eddfa96","attributes":{"name":"Row05956","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"9fccfc3f-caa9-4a98-b7b9-df385bdfd316","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b1241775-e3de-4eb3-858a-7715783fb75c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"440096c6-6fc2-4a81-bc7b-cfb56706f6cf","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1f127974-3f4a-4b02-aeda-56b2b2583d74","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"1d1d2900-15e5-433f-b8da-2d34d9be6e4d","attributes":{"name":"Column05953","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9fccfc3f-caa9-4a98-b7b9-df385bdfd316"},{"id":"b1241775-e3de-4eb3-858a-7715783fb75c"},{"id":"440096c6-6fc2-4a81-bc7b-cfb56706f6cf"},{"id":"1f127974-3f4a-4b02-aeda-56b2b2583d74"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"25c4d5b1-0664-4e38-ae88-fefe2c67e711","attributes":{"name":"Column05936","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9fccfc3f-caa9-4a98-b7b9-df385bdfd316"},{"id":"b1241775-e3de-4eb3-858a-7715783fb75c"},{"id":"440096c6-6fc2-4a81-bc7b-cfb56706f6cf"},{"id":"1f127974-3f4a-4b02-aeda-56b2b2583d74"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"440d8fc2-a772-4f02-afab-bdbc9c7ca631","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"9fccfc3f-caa9-4a98-b7b9-df385bdfd316"},{"id":"440096c6-6fc2-4a81-bc7b-cfb56706f6cf"},{"id":"1f127974-3f4a-4b02-aeda-56b2b2583d74"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}}]}},{"type":"object","name":"Figure","id":"28b07cb9-0100-4de0-8d0e-8b116e26ac57","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"19bf40e7-e4e9-4f6d-85cd-0b6041884eaf","attributes":{"tags":[[["Explained_by_GDP","Explained_by_GDP",null]],[]],"start":-0.22000000000000003,"end":2.4200000000000004,"reset_start":-0.22000000000000003,"reset_end":2.4200000000000004}},"y_range":{"type":"object","name":"Range1d","id":"b26c215e-d6d4-4832-ae26-ce37834b28ba","attributes":{"tags":[[["Happiness","Happiness",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":1.2607,"end":8.440299999999999,"reset_start":1.2607,"reset_end":8.440299999999999}},"x_scale":{"type":"object","name":"LinearScale","id":"20a8a012-34cf-44e5-86f0-ff2a46210eca"},"y_scale":{"type":"object","name":"LinearScale","id":"5f5ba59d-24c1-41c3-a03a-25f4d1ee7875"},"title":{"type":"object","name":"Title","id":"e01e1168-f940-4c7f-9814-92fa051d87d7","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"bc09ce0e-ca4c-4201-9bba-80a55c78657a","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"b8a6e ...

# %%
yaxis_happiness_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Explained_by_Trust', 'Explained_by_Freedom', 'Explained_by_GDP', 'Explained_by_Health', 'Explained_by_Social_support'], 
    button_type='success'
)

# %%
continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

# %%
happyness_source_bar_pipeline = (
    idf[
        (idf.Year == year_slider) &
        (idf.Kontinent.isin(continents_excl_world))
    ]
    .groupby(['Year', 'Kontinent'])[yaxis_happiness_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happyness_source_bar_plot =happyness_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='Kontinent', 
                                                     y=yaxis_happiness_source, 
                                                     title='Happyness source by continent')

# %%
happyness_source_bar_plot
# Out:
# <div id='25152912-a207-44cd-857a-67e7b7041314'>
#   <div id="bea8d25f-062d-45b9-8283-d1bdf608af6c" data-root-id="25152912-a207-44cd-857a-67e7b7041314" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"788dcfce-0d61-4584-8011-7ff057071b51":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"25152912-a207-44cd-857a-67e7b7041314","attributes":{"name":"Row06832","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"287b6dda-29fc-40c2-8003-84ad122e494e","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f89bf0dc-099a-492b-bddb-8c63368d4d9c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"36567f58-0f79-4894-a835-220f9ee54ce6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c2f2d7c2-6593-4eda-b961-21cea9971c9d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"c6434672-cb36-4f1a-9f92-124fb716e70a","attributes":{"name":"Column06829","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"287b6dda-29fc-40c2-8003-84ad122e494e"},{"id":"f89bf0dc-099a-492b-bddb-8c63368d4d9c"},{"id":"36567f58-0f79-4894-a835-220f9ee54ce6"},{"id":"c2f2d7c2-6593-4eda-b961-21cea9971c9d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"3601b5d3-3ca2-481d-aa9f-c168e767a190","attributes":{"name":"Column06812","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"287b6dda-29fc-40c2-8003-84ad122e494e"},{"id":"f89bf0dc-099a-492b-bddb-8c63368d4d9c"},{"id":"36567f58-0f79-4894-a835-220f9ee54ce6"},{"id":"c2f2d7c2-6593-4eda-b961-21cea9971c9d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"4497fea7-9327-4383-bd5f-64cfbcc3f0a9","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"287b6dda-29fc-40c2-8003-84ad122e494e"},{"id":"36567f58-0f79-4894-a835-220f9ee54ce6"},{"id":"c2f2d7c2-6593-4eda-b961-21cea9971c9d"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"706d1eaf-0e38-4301-a526-01326c03bc69","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"287b6dda-29fc-40c2-8003-84ad122e494e"},{"type":"object","name":"ImportedStyleSheet","id":"16c2c38e-a575-43e9-b607-2d48baafc86c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"36567f58-0f79-4894-a835-220f9ee54ce6"},{"id":"c2f2d7c2-6593-4eda-b961-21cea9971c9d"}],"margin":[5,10],"align":"start","labels":["Explained_by_Trust","Explained_by_Freedom","Explained_by_GDP","Explained_by_Health","Explained_by_Social_support"],"active":0}}]}},{"type":"object","name":"Figure","id":"61d74efa-c024-4b27-9e44-9408e7e76676","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"e09ecec2-bd1b-43c4-ad2f-8e240e75d10a","attributes":{"tags":[[["Kontinent","Kontinent",null]],[]],"factors":["Africa","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","i ...

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World Happyness dashboard', 
    sidebar=[pn.pane.Markdown("# Happyness"), 
             pn.pane.Markdown("####GDP is the biggest contributor to happyness."), 
             pn.pane.PNG('happy.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_Happy, 
                           happy_plot.panel(width=700), margin=(0,25)), 
                 happy_table.panel(width=500)), 
          pn.Row(pn.Column(happyness_source_bar_plot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_happiness_source, happyness_source_bar_pipeline.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

# %%
template.show()
# Out:
# Launching server at http://localhost:50382
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='947308bd-987f-45c3-bc39-c4294b92c98f', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='2f74bd95-d173-43c1-aaad-3ffb2c96bac4', ...)

# %%
template.servable();
