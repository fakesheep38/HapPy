# %%
#import geoviews as gv
#import geoviews.tile_sources as gvts

# %%
import pandas as pd
import numpy as np
import hvplot.pandas
import panel as pn
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('merged_data.csv')

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# 0                    0.126                0.535                        1.585
# 1                    0.208                0.537                        1.548
# 2                    0.250                0.559                        1.620
# 3                    0.124                0.577                        1.521
# 4                    0.251                0.545                        1.488
#
#    Dystopia_Residual
# 0              2.363
# 1              2.084
# 2              2.250
# 3              2.691
# 4              2.110

# %%
value_to_delete = 'xx'
df = df[df['Country'] != value_to_delete]

# %%
#mittelwerte = df.mean()
#df = df.append(mittelwerte, ignore_index=True) 
#Werte für World sind noch nicht berechnet

# %%
df = df.dropna()

# %%
country_to_continent = {
    'Finland': 'Europe',
    'Denmark': 'Europe',
    'Iceland': 'Europe',
    'Israel': 'Asia',
    'Netherlands': 'Europe',
    'Sweden': 'Europe',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Luxembourg': 'Europe',
    'New Zealand': 'Oceania',
    'Austria': 'Europe',
    'Australia': 'Oceania',
    'Canada': 'North America',
    'Ireland': 'Europe',
    'United States': 'North America',
    'Germany': 'Europe',
    'Belgium': 'Europe',
    'Czechia': 'Europe',
    'United Kingdom': 'Europe',
    'Lithuania': 'Europe',
    'France': 'Europe',
    'Slovenia': 'Europe',
    'Costa Rica': 'North America',
    'Romania': 'Europe',
    'Singapore': 'Asia',
    'United Arab Emirates': 'Asia',
    'Taiwan Province of China': 'Asia',
    'Uruguay': 'South America',
    'Slovakia': 'Europe',
    'Saudi Arabia': 'Asia',
    'Estonia': 'Europe',
    'Spain': 'Europe',
    'Italy': 'Europe',
    'Kosovo': 'Europe',
    'Chile': 'South America',
    'Mexico': 'North America',
    'Malta': 'Europe',
    'Panama': 'North America',
    'Poland': 'Europe',
    'Nicaragua': 'North America',
    'Latvia': 'Europe',
    'Bahrain': 'Asia',
    'Guatemala': 'North America',
    'Kazakhstan': 'Asia',
    'Serbia': 'Europe',
    'Cyprus': 'Europe',
    'Japan': 'Asia',
    'Croatia': 'Europe',
    'Brazil': 'South America',
    'El Salvador': 'North America',
    'Hungary': 'Europe',
    'Argentina': 'South America',
    'Honduras': 'North America',
    'Uzbekistan': 'Asia',
    'Malaysia': 'Asia',
    'Portugal': 'Europe',
    'South Korea': 'Asia',
    'Greece': 'Europe',
    'Mauritius': 'Africa',
    'Thailand': 'Asia',
    'Mongolia': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Moldova': 'Europe',
    'China': 'Asia',
    'Vietnam': 'Asia',
    'Paraguay': 'South America',
    'Montenegro': 'Europe',
    'Jamaica': 'North America',
    'Bolivia': 'South America',
    'Russia': 'Europe',
    'Bosnia and Herzegovina': 'Europe',
    'Colombia': 'South America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Bulgaria': 'Europe',
    'Nepal': 'Asia',
    'Armenia': 'Asia',
    'Tajikistan': 'Asia',
    'Algeria': 'Africa',
    'Hong Kong S.A.R. of China': 'Asia',
    'Albania': 'Europe',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Congo (Brazzaville)': 'Africa',
    'North Macedonia': 'Europe',
    'Venezuela': 'South America',
    'Laos': 'Asia',
    'Georgia': 'Asia',
    'Guinea': 'Africa',
    'Ukraine': 'Europe',
    'Ivory Coast': 'Africa',
    'Gabon': 'Africa',
    'Nigeria': 'Africa',
    'Cameroon': 'Africa',
    'Mozambique': 'Africa',
    'Iraq': 'Asia',
    'State of Palestine': 'Asia',
    'Morocco': 'Africa',
    'Iran': 'Asia',
    'Senegal': 'Africa',
    'Mauritania': 'Africa',
    'Burkina Faso': 'Africa',
    'Namibia': 'Africa',
    'Turkiye': 'Asia',
    'Ghana': 'Africa',
    'Pakistan': 'Asia',
    'Niger': 'Africa',
    'Tunisia': 'Africa',
    'Kenya': 'Africa',
    'Sri Lanka': 'Asia',
    'Uganda': 'Africa',
    'Chad': 'Africa',
    'Cambodia': 'Asia',
    'Benin': 'Africa',
    'Myanmar': 'Asia',
    'Bangladesh': 'Asia',
    'Gambia': 'Africa',
    'Mali': 'Africa',
    'Egypt': 'Africa',
    'Togo': 'Africa',
    'Jordan': 'Asia',
    'Ethiopia': 'Africa',
    'Liberia': 'Africa',
    'India': 'Asia',
    'Madagascar': 'Africa',
    'Zambia': 'Africa',
    'Tanzania': 'Africa',
    'Comoros': 'Africa',
    'Malawi': 'Africa',
    'Botswana': 'Africa',
    'Congo (Kinshasa)': 'Africa',
    'Zimbabwe': 'Africa',
    'Sierra Leone': 'Africa',
    'Lebanon': 'Asia',
    'Afghanistan': 'Asia',
    'Luxembourg*': 'Europe',
    'Guatemala*': 'North America',
    'Kuwait*': 'Asia',
    'Belarus*': 'Europe',
    'Turkmenistan*': 'Asia',
    'North Cyprus*': 'Europe',
    'Libya*': 'Africa',
    'Azerbaijan*': 'Asia',
    'Gambia*': 'Africa',
    'Liberia*': 'Africa',
    'Congo': 'Africa',
    'Niger*': 'Africa',
    'Turkey': 'Asia',
    'Comoros*': 'Africa',
    'Palestinian Territories*': 'Asia',
    'Eswatini, Kingdom of*': 'Africa',
    'Madagascar*': 'Africa',
    'Chad*': 'Africa',
    'Yemen*': 'Asia',
    'Mauritania*': 'Africa',
    'Lesotho*': 'Africa',
    'Botswana*': 'Africa',
    'Rwanda*': 'Africa',
    'xx': 'Unknown',
    'Czech Republic': 'Europe',
    'Kuwait': 'Asia',
    'North Cyprus': 'Europe',
    'Belarus': 'Europe',
    'Libya': 'Africa',
    'Maldives': 'Asia',
    'Azerbaijan': 'Asia',
    'Turkmenistan': 'Asia',
    'Palestinian Territories': 'Asia',
    'Swaziland': 'Africa',
    'Burundi': 'Africa',
    'Yemen': 'Asia',
    'Haiti': 'North America',
    'Lesotho': 'Africa',
    'Rwanda': 'Africa',
    'Trinidad and Tobago': 'North America',
    'Macedonia': 'Europe',
    'Central African Republic': 'Africa',
    'South Sudan': 'Africa',
    'Taiwan': 'Asia',
    'Qatar': 'Asia',
    'Trinidad & Tobago': 'North America',
    'Northern Cyprus': 'Europe',
    'Hong Kong': 'Asia',
    'Bhutan': 'Asia',
    'Somalia': 'Africa',
    'Syria': 'Asia',
    'Belize': 'North America',
    'Sudan': 'Africa',
    'Angola': 'Africa',
    'Hong Kong S.A.R., China': 'Asia',
    'Puerto Rico': 'North America',
    'Suriname': 'South America',
    'Somaliland Region': 'Africa',
    'Oman': 'Asia',
    'Somaliland region': 'Africa',
    'Djibouti': 'Africa',
}

# %%
df['Kontinent'] = df['Country'].map(country_to_continent)

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2015, end=2024, step=1, value=2017)
year_slider
# Out:
# IntSlider(end=2024, name='Year slider', start=2015, value=2017)

# %%
# Radio buttons for Happiness
yaxis_Happy = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness', 'Happiness_Rank',],
    button_type='success'
)

# %%
display(yaxis_Happy)
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Happiness', ...], value='Happiness')

# %%
continents = [ 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']#'World',

happy_pipeline = (
    idf[
        (idf.Year >= year_slider) &
        (idf.Kontinent.isin(continents))
    ]
    .groupby(['Kontinent', 'Year'])[yaxis_Happy].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happy_pipeline
# Out:
# <div id='8c669996-d73a-497e-a43b-789d6c3817da'>
#   <div id="c5717ddf-618e-450d-8561-b6adbe5539d8" data-root-id="8c669996-d73a-497e-a43b-789d6c3817da" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f7cf9900-986a-4859-90c0-f0bd4f1cdcd2":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"8c669996-d73a-497e-a43b-789d6c3817da","attributes":{"name":"Row01493","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"15ff13a9-bdfd-463e-ba6a-893abb443a44","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"85d2d034-a6a8-4598-8150-92bcd8eefd67","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2b16cbfb-aaae-43f0-8991-0b5a98f13c19","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8a3ef740-64e8-4130-baa2-4e9806473060","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ff526c76-c0c4-4dff-bf9d-d4b195a22121","attributes":{"name":"Column01490","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"15ff13a9-bdfd-463e-ba6a-893abb443a44"},{"id":"85d2d034-a6a8-4598-8150-92bcd8eefd67"},{"id":"2b16cbfb-aaae-43f0-8991-0b5a98f13c19"},{"id":"8a3ef740-64e8-4130-baa2-4e9806473060"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"447207e2-ed4a-4774-98e1-6a570c5189f9","attributes":{"name":"Column01460","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"15ff13a9-bdfd-463e-ba6a-893abb443a44"},{"id":"85d2d034-a6a8-4598-8150-92bcd8eefd67"},{"id":"2b16cbfb-aaae-43f0-8991-0b5a98f13c19"},{"id":"8a3ef740-64e8-4130-baa2-4e9806473060"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"f35e2961-6732-42cc-b120-cdaa10329c21","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"15ff13a9-bdfd-463e-ba6a-893abb443a44"},{"id":"2b16cbfb-aaae-43f0-8991-0b5a98f13c19"},{"id":"8a3ef740-64e8-4130-baa2-4e9806473060"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"1f031fd5-3ad9-467d-8cd2-4ce6eaefc75d","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"15ff13a9-bdfd-463e-ba6a-893abb443a44"},{"type":"object","name":"ImportedStyleSheet","id":"a962a1d4-310d-4b79-968b-e443a734ac10","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"2b16cbfb-aaae-43f0-8991-0b5a98f13c19"},{"id":"8a3ef740-64e8-4130-baa2-4e9806473060"}],"margin":[5,10],"align":"start","labels":["Happiness","Happiness_Rank"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"bf8d9a7e-f03f-49fc-8cab-596ebeadc235","attributes":{"name":"Column01475","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":
attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"bb25a237-5d01-4510-abbf-c0d5b9f1cff6"},{"id":"bfaad4c6-58dd-4986-871e-023fefe23057"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataf ...

# %%
happy_vs_GDP_scatterplot = happy_vs_GDP_scatterplot_pipeline.hvplot.scatter(x='Explained_by_GDP', 
                                                                y='Happiness', 
                                                                by='Kontinent', 
                                                                size=80,  
                                                                alpha=0.7,
                                                                height=500, 
                                                                width=500)

# %%
happy_vs_GDP_scatterplot
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='e6ebd79e-43c2-455e-82a9-37de3af953fb'>
#   <div id="cee14eba-c035-4359-bf6d-ed89c2caca86" data-root-id="e6ebd79e-43c2-455e-82a9-37de3af953fb" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9da8f53e-92ab-4619-9d25-c4b4a6825019":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"e6ebd79e-43c2-455e-82a9-37de3af953fb","attributes":{"name":"Row13008","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"1af94329-c3bb-4e58-90ec-620cab6af6b7","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b57e3c20-1448-4df7-b78a-3ffa3ea5ac9f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ae5fe179-9500-489a-889d-cf2a67ff9b3d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"27007551-d76d-4fca-a968-b12a8b1e31cc","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"28ed0bd3-6014-4149-99fa-f1572f6a6c84","attributes":{"name":"Column13005","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1af94329-c3bb-4e58-90ec-620cab6af6b7"},{"id":"b57e3c20-1448-4df7-b78a-3ffa3ea5ac9f"},{"id":"ae5fe179-9500-489a-889d-cf2a67ff9b3d"},{"id":"27007551-d76d-4fca-a968-b12a8b1e31cc"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"24a70b86-af7f-4499-9bbc-9d8fd7072632","attributes":{"name":"Column12988","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1af94329-c3bb-4e58-90ec-620cab6af6b7"},{"id":"b57e3c20-1448-4df7-b78a-3ffa3ea5ac9f"},{"id":"ae5fe179-9500-489a-889d-cf2a67ff9b3d"},{"id":"27007551-d76d-4fca-a968-b12a8b1e31cc"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"2b439d04-bded-468d-9e80-0325798d19b6","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1af94329-c3bb-4e58-90ec-620cab6af6b7"},{"id":"ae5fe179-9500-489a-889d-cf2a67ff9b3d"},{"type":"object","name":"ImportedStyleSheet","id":"683cc504-3749-4bc9-8a9f-7c5f92824952","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/fast.css"}}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2016}}]}},{"type":"object","name":"Figure","id":"1756651b-80d4-4187-91c7-13810e97dd87","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"fe9b0cfc-16e1-43b2-ae84-2d9150760bc5","attributes":{"tags":[[["Explained_by_GDP","Explained_by_GDP",null]],[]],"start":-0.22000000000000003,"end":2.4200000000000004,"reset_start":-0.22000000000000003,"reset_end":2.4200000000000004}},"y_range":{"type":"object","name":"Range1d","id":"9cc5159e-18a8-4447-a2ba-2d9654c33f34","attributes":{"tags":[[["Happiness","Happiness",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":1.2607,"end":8.440299999999999,"reset_start":1.2607,"reset_end":8.440299999999999}},"x_scale":{"type":"object","name":"LinearScale","id":"a7761724-99f2-4bbb-b625-43359e634f4c"},"y_scale":{"type":"object","name":"LinearScale","id":"120ee49f-2a9c-4a5d-9517-6cb1171396b9"},"title":{"type":"object","name":"Title","id":"59114018-906a-4d5b-92fb-c2e81c1a4012","attributes":{"text_color":"black","text_font_size":"12pt"}},"rendere ...

# %%
yaxis_happiness_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Explained_by_Trust', 'Explained_by_Freedom', 'Explained_by_GDP', 'Explained_by_Health', 'Explained_by_Social_support'], 
    button_type='success'
)

# %%
continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

# %%
happyness_source_bar_pipeline = (
    idf[
        (idf.Year == year_slider) &
        (idf.Kontinent.isin(continents_excl_world))
    ]
    .groupby(['Year', 'Kontinent'])[yaxis_happiness_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happyness_source_bar_plot =happyness_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='Kontinent', 
                                                     y=yaxis_happiness_source, 
                                                     title='Happyness source by continent')

# %%
happyness_source_bar_plot
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='5fbc4017-2610-44ac-b7aa-ea6d7a03c47b'>
#   <div id="bc8d337b-6d39-4f72-ba99-df9422d6e713" data-root-id="5fbc4017-2610-44ac-b7aa-ea6d7a03c47b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"94091be9-a715-49bd-b4e4-dd8fed628d2d":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"5fbc4017-2610-44ac-b7aa-ea6d7a03c47b","attributes":{"name":"Row03607","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"701ccc62-0ea4-483b-9a4b-06d1e48c4821","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"80e89d0e-736f-45d7-a542-05ba4675d097","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5a9b8274-7280-448c-93d9-32989fe24ce8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3d2ddda0-a16b-49fa-893d-781b801f4613","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"b4723f38-4678-45e0-83b5-5a31ff1e8fa2","attributes":{"name":"Column03604","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"701ccc62-0ea4-483b-9a4b-06d1e48c4821"},{"id":"80e89d0e-736f-45d7-a542-05ba4675d097"},{"id":"5a9b8274-7280-448c-93d9-32989fe24ce8"},{"id":"3d2ddda0-a16b-49fa-893d-781b801f4613"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c500e150-c40b-4d80-b878-e001c6a0c2c5","attributes":{"name":"Column03587","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"701ccc62-0ea4-483b-9a4b-06d1e48c4821"},{"id":"80e89d0e-736f-45d7-a542-05ba4675d097"},{"id":"5a9b8274-7280-448c-93d9-32989fe24ce8"},{"id":"3d2ddda0-a16b-49fa-893d-781b801f4613"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"fd9b29d6-4cf4-46ae-89bb-97b12558bc46","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"701ccc62-0ea4-483b-9a4b-06d1e48c4821"},{"id":"5a9b8274-7280-448c-93d9-32989fe24ce8"},{"id":"3d2ddda0-a16b-49fa-893d-781b801f4613"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"fa5612bb-fc5c-44e2-ad5e-565227381caa","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"701ccc62-0ea4-483b-9a4b-06d1e48c4821"},{"type":"object","name":"ImportedStyleSheet","id":"9a4ac8c1-b76d-451c-961b-c127a340218b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"5a9b8274-7280-448c-93d9-32989fe24ce8"},{"id":"3d2ddda0-a16b-49fa-893d-781b801f4613"}],"margin":[5,10],"align":"start","labels":["Explained_by_Trust","Explained_by_Freedom","Explained_by_GDP","Explained_by_Health","Explained_by_Social_support"],"active":0}}]}},{"type":"object","name":"Figure","id":"c6607686-845b-4349-830e-dedcb78b820a","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"35523aee-fce0-4fbb-8031-965d950f32ba","attributes":{"tags":[[["Kontinent","Kontinent",null]],[]],"factors":["Africa","Asia","Europe","North America","Oceania","South America"]}},"y_ran ...

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World Happyness dashboard', 
    sidebar=[pn.pane.Markdown("# Happyness"), 
             pn.pane.Markdown("####GDP is the biggest contributor to happyness."), 
             pn.pane.PNG('happy.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_Happy, 
                           happy_plot.panel(width=700), margin=(0,25)), 
                 happy_table.panel(width=500)), 
          pn.Row(pn.Column(happyness_source_bar_plot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_happiness_source, happyness_source_bar_pipeline.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

# %%
template.show()
# Out:
# Launching server at http://localhost:57788

# %%
template.servable();
