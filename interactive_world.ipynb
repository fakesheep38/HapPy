# %%
import panel as pn

# %%
import pandas as pd
import hvplot.pandas

# %%
#import geoviews as gv

# %%
import numpy as np
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#import geoviews.tile_sources as gvts

# %%
df = pd.read_csv('merged_data.csv')

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# 0                    0.126                0.535                        1.585
# 1                    0.208                0.537                        1.548
# 2                    0.250                0.559                        1.620
# 3                    0.124                0.577                        1.521
# 4                    0.251                0.545                        1.488
#
#    Dystopia_Residual
# 0              2.363
# 1              2.084
# 2              2.250
# 3              2.691
# 4              2.110

# %%
value_to_delete = 'xx'
df = df[df['Country'] != value_to_delete]

# %%
df = df.dropna()

# %%
country_to_continent = {
    'Finland': 'Europe',
    'Denmark': 'Europe',
    'Iceland': 'Europe',
    'Israel': 'Asia',
    'Netherlands': 'Europe',
    'Sweden': 'Europe',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Luxembourg': 'Europe',
    'New Zealand': 'Oceania',
    'Austria': 'Europe',
    'Australia': 'Oceania',
    'Canada': 'North America',
    'Ireland': 'Europe',
    'United States': 'North America',
    'Germany': 'Europe',
    'Belgium': 'Europe',
    'Czechia': 'Europe',
    'United Kingdom': 'Europe',
    'Lithuania': 'Europe',
    'France': 'Europe',
    'Slovenia': 'Europe',
    'Costa Rica': 'North America',
    'Romania': 'Europe',
    'Singapore': 'Asia',
    'United Arab Emirates': 'Asia',
    'Taiwan Province of China': 'Asia',
    'Uruguay': 'South America',
    'Slovakia': 'Europe',
    'Saudi Arabia': 'Asia',
    'Estonia': 'Europe',
    'Spain': 'Europe',
    'Italy': 'Europe',
    'Kosovo': 'Europe',
    'Chile': 'South America',
    'Mexico': 'North America',
    'Malta': 'Europe',
    'Panama': 'North America',
    'Poland': 'Europe',
    'Nicaragua': 'North America',
    'Latvia': 'Europe',
    'Bahrain': 'Asia',
    'Guatemala': 'North America',
    'Kazakhstan': 'Asia',
    'Serbia': 'Europe',
    'Cyprus': 'Europe',
    'Japan': 'Asia',
    'Croatia': 'Europe',
    'Brazil': 'South America',
    'El Salvador': 'North America',
    'Hungary': 'Europe',
    'Argentina': 'South America',
    'Honduras': 'North America',
    'Uzbekistan': 'Asia',
    'Malaysia': 'Asia',
    'Portugal': 'Europe',
    'South Korea': 'Asia',
    'Greece': 'Europe',
    'Mauritius': 'Africa',
    'Thailand': 'Asia',
    'Mongolia': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Moldova': 'Europe',
    'China': 'Asia',
    'Vietnam': 'Asia',
    'Paraguay': 'South America',
    'Montenegro': 'Europe',
    'Jamaica': 'North America',
    'Bolivia': 'South America',
    'Russia': 'Europe',
    'Bosnia and Herzegovina': 'Europe',
    'Colombia': 'South America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Bulgaria': 'Europe',
    'Nepal': 'Asia',
    'Armenia': 'Asia',
    'Tajikistan': 'Asia',
    'Algeria': 'Africa',
    'Hong Kong S.A.R. of China': 'Asia',
    'Albania': 'Europe',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Congo (Brazzaville)': 'Africa',
    'North Macedonia': 'Europe',
    'Venezuela': 'South America',
    'Laos': 'Asia',
    'Georgia': 'Asia',
    'Guinea': 'Africa',
    'Ukraine': 'Europe',
    'Ivory Coast': 'Africa',
    'Gabon': 'Africa',
    'Nigeria': 'Africa',
    'Cameroon': 'Africa',
    'Mozambique': 'Africa',
    'Iraq': 'Asia',
    'State of Palestine': 'Asia',
    'Morocco': 'Africa',
    'Iran': 'Asia',
    'Senegal': 'Africa',
    'Mauritania': 'Africa',
    'Burkina Faso': 'Africa',
    'Namibia': 'Africa',
    'Turkiye': 'Asia',
    'Ghana': 'Africa',
    'Pakistan': 'Asia',
    'Niger': 'Africa',
    'Tunisia': 'Africa',
    'Kenya': 'Africa',
    'Sri Lanka': 'Asia',
    'Uganda': 'Africa',
    'Chad': 'Africa',
    'Cambodia': 'Asia',
    'Benin': 'Africa',
    'Myanmar': 'Asia',
    'Bangladesh': 'Asia',
    'Gambia': 'Africa',
    'Mali': 'Africa',
    'Egypt': 'Africa',
    'Togo': 'Africa',
    'Jordan': 'Asia',
    'Ethiopia': 'Africa',
    'Liberia': 'Africa',
    'India': 'Asia',
    'Madagascar': 'Africa',
    'Zambia': 'Africa',
    'Tanzania': 'Africa',
    'Comoros': 'Africa',
    'Malawi': 'Africa',
    'Botswana': 'Africa',
    'Congo (Kinshasa)': 'Africa',
    'Zimbabwe': 'Africa',
    'Sierra Leone': 'Africa',
    'Lebanon': 'Asia',
    'Afghanistan': 'Asia',
    'Luxembourg*': 'Europe',
    'Guatemala*': 'North America',
    'Kuwait*': 'Asia',
    'Belarus*': 'Europe',
    'Turkmenistan*': 'Asia',
    'North Cyprus*': 'Europe',
    'Libya*': 'Africa',
    'Azerbaijan*': 'Asia',
    'Gambia*': 'Africa',
    'Liberia*': 'Africa',
    'Congo': 'Africa',
    'Niger*': 'Africa',
    'Turkey': 'Asia',
    'Comoros*': 'Africa',
    'Palestinian Territories*': 'Asia',
    'Eswatini, Kingdom of*': 'Africa',
    'Madagascar*': 'Africa',
    'Chad*': 'Africa',
    'Yemen*': 'Asia',
    'Mauritania*': 'Africa',
    'Lesotho*': 'Africa',
    'Botswana*': 'Africa',
    'Rwanda*': 'Africa',
    'xx': 'Unknown',
    'Czech Republic': 'Europe',
    'Kuwait': 'Asia',
    'North Cyprus': 'Europe',
    'Belarus': 'Europe',
    'Libya': 'Africa',
    'Maldives': 'Asia',
    'Azerbaijan': 'Asia',
    'Turkmenistan': 'Asia',
    'Palestinian Territories': 'Asia',
    'Swaziland': 'Africa',
    'Burundi': 'Africa',
    'Yemen': 'Asia',
    'Haiti': 'North America',
    'Lesotho': 'Africa',
    'Rwanda': 'Africa',
    'Trinidad and Tobago': 'North America',
    'Macedonia': 'Europe',
    'Central African Republic': 'Africa',
    'South Sudan': 'Africa',
    'Taiwan': 'Asia',
    'Qatar': 'Asia',
    'Trinidad & Tobago': 'North America',
    'Northern Cyprus': 'Europe',
    'Hong Kong': 'Asia',
    'Bhutan': 'Asia',
    'Somalia': 'Africa',
    'Syria': 'Asia',
    'Belize': 'North America',
    'Sudan': 'Africa',
    'Angola': 'Africa',
    'Hong Kong S.A.R., China': 'Asia',
    'Puerto Rico': 'North America',
    'Suriname': 'South America',
    'Somaliland Region': 'Africa',
    'Oman': 'Asia',
    'Somaliland region': 'Africa',
    'Djibouti': 'Africa',
}

# %%
df['Kontinent'] = df['Country'].map(country_to_continent)

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2015, end=2023, step=1, value=2017)
year_slider
# Out:
# IntSlider(end=2023, name='Year slider', start=2015, value=2017)

# %%
# Radio buttons for Happiness
yaxis_Happy = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness', 'Happiness_Rank'],
    button_type='success'
)

# %%
display(yaxis_Happy)
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Happiness', ...], value='Happiness')

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

happy_pipeline = (
    idf[
        (idf.Year <= year_slider) &
        (idf.Kontinent.isin(continents))
    ]
    .groupby(['Kontinent', 'Year'])[yaxis_Happy].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happy_plot = happy_pipeline.hvplot(x = 'Year', by='Kontinent', y=yaxis_Happy,line_width=2, title="Happyness by Continent")

# %%
happy_plot
# Out:
# <div id='718bca7b-345a-4a58-b71c-454a5342fff1'>
#   <div id="bd09bd8d-12a2-410b-8436-69c93ad1d00a" data-root-id="718bca7b-345a-4a58-b71c-454a5342fff1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d78032c9-07e4-47fe-beb1-45d82504c457":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"718bca7b-345a-4a58-b71c-454a5342fff1","attributes":{"name":"Row11574","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"86a8654c-6a94-4e90-8b52-65e2758b3c3f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a3eba979-f28e-4cb5-9266-1d47ca6f90c8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f8fdca0c-5db0-4440-8820-7e3ca93d65e9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1dc73637-aa20-4352-b98c-a3fdfb317c4c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"50f66bb8-c986-45eb-b7d4-5ebdad03e481","attributes":{"name":"Column11571","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"86a8654c-6a94-4e90-8b52-65e2758b3c3f"},{"id":"a3eba979-f28e-4cb5-9266-1d47ca6f90c8"},{"id":"f8fdca0c-5db0-4440-8820-7e3ca93d65e9"},{"id":"1dc73637-aa20-4352-b98c-a3fdfb317c4c"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":
stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d43f7095-3d2d-48f3-83a2-a607842a554c"},{"id":"a2504345-eb7f-492e-9ce0-e72d2ac012b0"},{"id":"70608387-9a66-4dee-97f2-1deb29087ea8"},{"id":"cf28c201-4129-471c-8680-2424765f30a1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"15f06415-12a6-4658-9cec-fbf3fdd127cf","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d43f7095-3d2d-48f3-83a2-a607842a554c"},{"type":"object","name":"ImportedStyleSheet","id":"16430825-813d-4cee-9db3-a5ba25166368","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/dataframe.css"}},{"id":"70608387-9a66-4dee-97f2-1deb29087ea8"},{"id":"cf28c201-4129-471c-8680-2424765f30a1"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=& ...

# %%
happy_vs_GDP_scatterplot = happy_vs_GDP_scatterplot_pipeline.hvplot(x='Explained_by_GDP', 
                                                                y='Happiness', 
                                                                by='Kontinent', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)

# %%
happy_vs_GDP_scatterplot
# Out:
# ---------------------------------------------------------------------------
# SkipRendering                             Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\interactive.py:393, in Interactive._repr_mimebundle_(self, include, exclude)
#     392 def _repr_mimebundle_(self, include=[], exclude=[]):
# --> 393     return self.layout()._repr_mimebundle_()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\viewable.py:818, in Viewable._repr_mimebundle_(self, include, exclude)
#     816 doc = Document()
#     817 comm = state._comm_manager.get_server_comm()
# --> 818 model = self._render_model(doc, comm)
#     819 if config.embed:
#     820     return render_model(model)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\viewable.py:736, in Viewable._render_model(self, doc, comm)
#     734 if comm is None:
#     735     comm = state._comm_manager.get_server_comm()
# --> 736 model = self.get_root(doc, comm)
#     738 if self._design and self._design.theme.bokeh_theme:
#     739     doc.theme = self._design.theme.bokeh_theme
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\layout\base.py:305, in Panel.get_root(self, doc, comm, preprocess)
#     301 def get_root(
#     302     self, doc: Optional[Document] = None, comm: Optional[Comm] = None,
#     303     preprocess: bool = True
#     304 ) -> Model:
# --> 305     root = super().get_root(doc, comm, preprocess)
#     306     # ALERT: Find a better way to handle this
#     307     if hasattr(root, 'styles') and 'overflow-x' in root.styles:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\viewable.py:658, in Renderable.get_root(self, doc, comm, preprocess)
#     656 wrapper = self._design._wrapper(self)
#     657 if wrapper is self:
# --> 658     root = self._get_model(doc, comm=comm)
#     659     if preprocess:
#     660         self._preprocess(root)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\layout\base.py:173, in Panel._get_model(self, doc, root, parent, comm)
#     171 root = root or model
#     172 self._models[root.ref['id']] = (model, parent)
# --> 173 objects, _ = self._get_objects(model, [], doc, root, comm)
#     174 props = self._get_properties(doc)
#     175 props[self._property_mapping['objects']] = objects
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\layout\base.py:155, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     153 else:
#     154     try:
# --> 155         child = pane._get_model(doc, root, model, comm)
#     156     except RerenderError as e:
#     157         if e.layout is not None and e.layout is not self:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\layout\base.py:173, in Panel._get_model(self, doc, root, parent, comm)
#     171 root = root or model
#     172 self._models[root.ref['id']] = (model, parent)
# --> 173 objects, _ = self._get_objects(model, [], doc, root, comm)
#     174 props = self._get_properties(doc)
#     175 props[self._property_mapping['objects']] = objects
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\layout\base.py:155, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     153 else:
#     154     try:
# --> 155         child = pane._get_model(doc, root, model, comm)
#     156     except RerenderError as e:
#     157         if e.layout is not None and e.layout is not self:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\pane\holoviews.py:411, in HoloViews._get_model(self, doc, root, parent, comm)
#     409     plot = self.object
#     410 else:
# --> 411     plot = self._render(doc, comm, root)
#     413 plot.pane = self
#     414 backend = plot.renderer.backend
#
# File C:\ProgramData\anaconda3\Lib\site-packages\panel\pane\holoviews.py:506, in HoloViews._render(self, doc, comm, root)
#     503     if comm:
#     504         kwargs['comm'] = comm
# --> 506 return renderer.get_plot(self.object, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\renderer.py:70, in BokehRenderer.get_plot(self_or_cls, obj, doc, renderer, **kwargs)
#      63 @bothmethod
#      64 def get_plot(self_or_cls, obj, doc=None, renderer=None, **kwargs):
#      65     """
#      66     Given a HoloViews Viewable return a corresponding plot instance.
#      67     Allows supplying a document attach the plot to, useful when
#      68     combining the bokeh model with another plot.
#      69     """
# ---> 70     plot = super().get_plot(obj, doc, renderer, **kwargs)
#      71     if plot.document is None:
#      72         plot.document = Document() if self_or_cls.notebook_context else curdoc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\renderer.py:236, in Renderer.get_plot(self_or_cls, obj, doc, renderer, comm, **kwargs)
#     234 if isinstance(obj, AdjointLayout):
#     235     obj = Layout(obj)
# --> 236 plot = self_or_cls.plotting_class(obj)(obj, renderer=renderer,
#     237                                        **plot_opts)
#     238 defaults = [kd.default for kd in plot.dimensions]
#     239 init_key = tuple(v if d is None else d for v, d in
#     240                  zip(plot.keys[0], defaults))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\element.py:2516, in OverlayPlot.__init__(self, overlay, **kwargs)
#    2514 def __init__(self, overlay, **kwargs):
#    2515     self._multi_y_propagation = self.lookup_options(overlay, 'plot').options.get('multi_y', False)
# -> 2516     super().__init__(overlay, **kwargs)
#    2517     self._multi_y_propagation = False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py:1713, in GenericOverlayPlot.__init__(self, overlay, ranges, batched, keys, group_counter, **params)
#    1711 self.cyclic_index_lookup = {}
#    1712 self.zoffset = 0
# -> 1713 self.subplots = self._create_subplots(ranges)
#    1714 self.traverse(lambda x: setattr(x, 'comm', self.comm))
#    1715 self.top_level = keys is None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py:1783, in GenericOverlayPlot._create_subplots(self, ranges)
#    1780         self.zoffset += len(subplot.subplots.keys()) - 1
#    1782 if not subplots:
# -> 1783     raise SkipRendering("%s backend could not plot any Elements "
#    1784                         "in the Overlay." % self.renderer.backend)
#    1785 return subplots
#
# SkipRendering: bokeh backend could not plot any Elements in the Overlay.

# %%
yaxis_happyness_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Explained_by_Trust', 'Explained_by_Freedom', 'Explained_by_GDP', 'Explained_by_Health', 'Explained_by_Social_support'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

happyness_source_bar_pipeline = (
    idf[
        (idf.Year == year_slider) &
        (idf.Kontinent.isin(continents_excl_world))
    ]
    .groupby(['Year', 'Country'])[yaxis_happiness_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happyness_source_bar_plot =happyness_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='Kontinent', 
                                                     y=yaxis_happiness_source, 
                                                     title='Happyness source by continent')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 happyness_source_bar_plot =happyness_source_bar_pipeline.hvplot(kind='bar',
#       2                                                      x='Kontinent',
#       3                                                      y=yaxis_happiness_source,
#       4                                                      title='Happyness source by continent')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\interactive.py:868, in _hvplot.__call__(self, _kind, *args, **kwargs)
#     866 transform = type(transform)(transform, 'hvplot', accessor=True)
#     867 dmap = 'kind' not in kwargs or isinstance(kwargs['kind'], str)
# --> 868 return new._clone(transform(*args, **kwargs), dmap=dmap)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\interactive.py:388, in Interactive._clone(self, transform, plot, loc, center, dmap, copy, max_rows, **kwargs)
#     386 else:
#     387     kwargs = dict(self._inherit_kwargs, **dict(self._kwargs, **kwargs))
# --> 388 return type(self)(self._obj, fn=self._fn, transform=transform, plot=plot, depth=depth,
#     389                  loc=loc, center=center, dmap=dmap, _shared_obj=self._shared_obj,
#     390                  max_rows=max_rows, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\interactive.py:282, in Interactive.__init__(self, obj, transform, fn, plot, depth, loc, center, dmap, inherit_kwargs, max_rows, method, _shared_obj, _current, **kwargs)
#     280     self._current_ = _current
#     281 else:
# --> 282     self._current_ = self._transform.apply(ds, keep_index=True, compute=False)
#     283 self._init = True
#     284 self._dirty = False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\util\transform.py:770, in dim.apply(self, dataset, flat, expanded, ranges, all_values, keep_index, compute, strict)
#     768     drange = ranges.get(eldim, {})
#     769     drange = drange.get('combined', drange)
# --> 770     data = self._apply_fn(dataset, data, fn, fn_name, args,
#     771                           kwargs, accessor, drange)
#     772 drop_index = keep_index_for_compute and not keep_index
#     773 compute = not compute_for_compute and compute
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\util\transform.py:670, in dim._apply_fn(self, dataset, data, fn, fn_name, args, kwargs, accessor, drange)
#     668                 data = method(*args, **kwargs)
#     669             else:
# --> 670                 raise e
#     671 else:
#     672     data = fn(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\util\transform.py:664, in dim._apply_fn(self, dataset, data, fn, fn_name, args, kwargs, accessor, drange)
#     662 else:
#     663     try:
# --> 664         data = method(*args, **kwargs)
#     665     except Exception as e:
#     666         if 'axis' in kwargs:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\converter.py:1249, in HoloViewsConverter.__call__(self, kind, x, y)
#    1247                 dataset = Dataset(data)
#    1248             dataset = dataset.redim(**self._redim)
# -> 1249         obj = method(x, y)
#    1250         obj._dataset = dataset
#    1252 if self.crs and self.project:
#    1253     # Apply projection before rasterizing
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\converter.py:1719, in HoloViewsConverter.bar(self, x, y, data)
#    1717 if (x or self.by) and y and (self.by or not isinstance(y, (list, tuple) or len(y) == 1)):
#    1718     y = y[0] if isinstance(y, (list, tuple)) else y
# -> 1719     return self.single_chart(Bars, x, y, data)
#    1720 return self._category_plot(Bars, x, list(y), data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\hvplot\converter.py:1542, in HoloViewsConverter.single_chart(self, element, x, y, data)
#    1540     chart = chart.layout() if self.subplots else chart.overlay(sort=False)
#    1541 else:
# -> 1542     chart = element(data, kdims, vdims).relabel(**self._relabel)
#    1543 return (chart.redim(**self._redim)
#    1544         .opts(cur_opts, backend='bokeh')
#    1545         .opts(compat_opts, backend=self._backend_compat))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\element\selection.py:24, in SelectionIndexExpr.__init__(self, *args, **kwargs)
#      23 def __init__(self, *args, **kwargs):
# ---> 24     super().__init__(*args, **kwargs)
#      25     self._index_skip = False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\element\chart.py:51, in Chart.__init__(self, data, kdims, vdims, **params)
#      49 if len(params.get('kdims', [])) == self._max_kdim_count + 1:
#      50     self.param.warning('Chart elements should only be supplied a single kdim')
# ---> 51 super().__init__(data, **params)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\core\data\__init__.py:333, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     331 (data, self.interface, dims, extra_kws) = initialized
#     332 super().__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
# --> 333 self.interface.validate(self, validate_vdims)
#     335 # Handle _pipeline property
#     336 if input_pipeline is None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:168, in PandasInterface.validate(cls, dataset, vdims)
#     166 not_found = [d for d in dimensions if d not in cols]
#     167 if not_found:
# --> 168     raise DataError("Supplied data does not contain specified "
#     169                     "dimensions, the following dimensions were "
#     170                     "not found: %s" % repr(not_found), cls)
#
# DataError: Supplied data does not contain specified dimensions, the following dimensions were not found: ['Kontinent']
#
# PandasInterface expects tabular data, for more information on supported datatypes see http://holoviews.org/user_guide/Tabular_Datasets.html

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World Happyness dashboard', 
    sidebar=[pn.pane.Markdown("# Happyness"), 
             pn.pane.Markdown("####GDP is the biggest contributor to happyness."), 
             pn.pane.PNG('happy.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_Happy, 
                           happy_plot.panel(width=700), margin=(0,25)), 
                 happy_table.panel(width=500)), 
          pn.Row(pn.Column(happyness_source_bar_plot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_happyness_source, happyness_source_bar_pipeline.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 12
#       1 #Layout using Template
#       2 template = pn.template.FastListTemplate(
#       3     title='World Happyness dashboard',
#       4     sidebar=[pn.pane.Markdown("# Happyness"),
#       5              pn.pane.Markdown("####GDP is the biggest contributor to happyness."),
#       6              pn.pane.PNG('happy.png', sizing_mode='scale_both'),
#       7              pn.pane.Markdown("## Settings"),
#       8              year_slider],
#       9     main=[pn.Row(pn.Column(yaxis_Happy,
#      10                            happy_plot.panel(width=700), margin=(0,25)),
#      11                  happy_table.panel(width=500)),
# ---> 12           pn.Row(pn.Column(happyness_source_bar_plot.panel(width=600), margin=(0,25)),
#      13                  pn.Column(yaxis_happyness_source, happyness_source_bar_pipeline.panel(width=600)))],
#      14     accent_base_color="#88d8b0",
#      15     header_background="#88d8b0",
#      16 )
#      17 # template.show()
#      18 template.servable()
#
# NameError: name 'happyness_source_bar_plot' is not defined
