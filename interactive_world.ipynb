# %%
#import geoviews as gv
#import geoviews.tile_sources as gvts

# %%
import pandas as pd
import numpy as np
import hvplot.pandas
import panel as pn
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('merged_data.csv')

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# 0                    0.126                0.535                        1.585
# 1                    0.208                0.537                        1.548
# 2                    0.250                0.559                        1.620
# 3                    0.124                0.577                        1.521
# 4                    0.251                0.545                        1.488
#
#    Dystopia_Residual
# 0              2.363
# 1              2.084
# 2              2.250
# 3              2.691
# 4              2.110

# %%
value_to_delete = 'xx'
df = df[df['Country'] != value_to_delete]

# %%
#mittelwerte = df.mean()
#df = df.append(mittelwerte, ignore_index=True) 
#Werte für World sind noch nicht berechnet

# %%
df = df.dropna()

# %%
country_to_continent = {
    'Finland': 'Europe',
    'Denmark': 'Europe',
    'Iceland': 'Europe',
    'Israel': 'Asia',
    'Netherlands': 'Europe',
    'Sweden': 'Europe',
    'Norway': 'Europe',
    'Switzerland': 'Europe',
    'Luxembourg': 'Europe',
    'New Zealand': 'Oceania',
    'Austria': 'Europe',
    'Australia': 'Oceania',
    'Canada': 'North America',
    'Ireland': 'Europe',
    'United States': 'North America',
    'Germany': 'Europe',
    'Belgium': 'Europe',
    'Czechia': 'Europe',
    'United Kingdom': 'Europe',
    'Lithuania': 'Europe',
    'France': 'Europe',
    'Slovenia': 'Europe',
    'Costa Rica': 'North America',
    'Romania': 'Europe',
    'Singapore': 'Asia',
    'United Arab Emirates': 'Asia',
    'Taiwan Province of China': 'Asia',
    'Uruguay': 'South America',
    'Slovakia': 'Europe',
    'Saudi Arabia': 'Asia',
    'Estonia': 'Europe',
    'Spain': 'Europe',
    'Italy': 'Europe',
    'Kosovo': 'Europe',
    'Chile': 'South America',
    'Mexico': 'North America',
    'Malta': 'Europe',
    'Panama': 'North America',
    'Poland': 'Europe',
    'Nicaragua': 'North America',
    'Latvia': 'Europe',
    'Bahrain': 'Asia',
    'Guatemala': 'North America',
    'Kazakhstan': 'Asia',
    'Serbia': 'Europe',
    'Cyprus': 'Europe',
    'Japan': 'Asia',
    'Croatia': 'Europe',
    'Brazil': 'South America',
    'El Salvador': 'North America',
    'Hungary': 'Europe',
    'Argentina': 'South America',
    'Honduras': 'North America',
    'Uzbekistan': 'Asia',
    'Malaysia': 'Asia',
    'Portugal': 'Europe',
    'South Korea': 'Asia',
    'Greece': 'Europe',
    'Mauritius': 'Africa',
    'Thailand': 'Asia',
    'Mongolia': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Moldova': 'Europe',
    'China': 'Asia',
    'Vietnam': 'Asia',
    'Paraguay': 'South America',
    'Montenegro': 'Europe',
    'Jamaica': 'North America',
    'Bolivia': 'South America',
    'Russia': 'Europe',
    'Bosnia and Herzegovina': 'Europe',
    'Colombia': 'South America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Bulgaria': 'Europe',
    'Nepal': 'Asia',
    'Armenia': 'Asia',
    'Tajikistan': 'Asia',
    'Algeria': 'Africa',
    'Hong Kong S.A.R. of China': 'Asia',
    'Albania': 'Europe',
    'Indonesia': 'Asia',
    'South Africa': 'Africa',
    'Congo (Brazzaville)': 'Africa',
    'North Macedonia': 'Europe',
    'Venezuela': 'South America',
    'Laos': 'Asia',
    'Georgia': 'Asia',
    'Guinea': 'Africa',
    'Ukraine': 'Europe',
    'Ivory Coast': 'Africa',
    'Gabon': 'Africa',
    'Nigeria': 'Africa',
    'Cameroon': 'Africa',
    'Mozambique': 'Africa',
    'Iraq': 'Asia',
    'State of Palestine': 'Asia',
    'Morocco': 'Africa',
    'Iran': 'Asia',
    'Senegal': 'Africa',
    'Mauritania': 'Africa',
    'Burkina Faso': 'Africa',
    'Namibia': 'Africa',
    'Turkiye': 'Asia',
    'Ghana': 'Africa',
    'Pakistan': 'Asia',
    'Niger': 'Africa',
    'Tunisia': 'Africa',
    'Kenya': 'Africa',
    'Sri Lanka': 'Asia',
    'Uganda': 'Africa',
    'Chad': 'Africa',
    'Cambodia': 'Asia',
    'Benin': 'Africa',
    'Myanmar': 'Asia',
    'Bangladesh': 'Asia',
    'Gambia': 'Africa',
    'Mali': 'Africa',
    'Egypt': 'Africa',
    'Togo': 'Africa',
    'Jordan': 'Asia',
    'Ethiopia': 'Africa',
    'Liberia': 'Africa',
    'India': 'Asia',
    'Madagascar': 'Africa',
    'Zambia': 'Africa',
    'Tanzania': 'Africa',
    'Comoros': 'Africa',
    'Malawi': 'Africa',
    'Botswana': 'Africa',
    'Congo (Kinshasa)': 'Africa',
    'Zimbabwe': 'Africa',
    'Sierra Leone': 'Africa',
    'Lebanon': 'Asia',
    'Afghanistan': 'Asia',
    'Luxembourg*': 'Europe',
    'Guatemala*': 'North America',
    'Kuwait*': 'Asia',
    'Belarus*': 'Europe',
    'Turkmenistan*': 'Asia',
    'North Cyprus*': 'Europe',
    'Libya*': 'Africa',
    'Azerbaijan*': 'Asia',
    'Gambia*': 'Africa',
    'Liberia*': 'Africa',
    'Congo': 'Africa',
    'Niger*': 'Africa',
    'Turkey': 'Asia',
    'Comoros*': 'Africa',
    'Palestinian Territories*': 'Asia',
    'Eswatini, Kingdom of*': 'Africa',
    'Madagascar*': 'Africa',
    'Chad*': 'Africa',
    'Yemen*': 'Asia',
    'Mauritania*': 'Africa',
    'Lesotho*': 'Africa',
    'Botswana*': 'Africa',
    'Rwanda*': 'Africa',
    'xx': 'Unknown',
    'Czech Republic': 'Europe',
    'Kuwait': 'Asia',
    'North Cyprus': 'Europe',
    'Belarus': 'Europe',
    'Libya': 'Africa',
    'Maldives': 'Asia',
    'Azerbaijan': 'Asia',
    'Turkmenistan': 'Asia',
    'Palestinian Territories': 'Asia',
    'Swaziland': 'Africa',
    'Burundi': 'Africa',
    'Yemen': 'Asia',
    'Haiti': 'North America',
    'Lesotho': 'Africa',
    'Rwanda': 'Africa',
    'Trinidad and Tobago': 'North America',
    'Macedonia': 'Europe',
    'Central African Republic': 'Africa',
    'South Sudan': 'Africa',
    'Taiwan': 'Asia',
    'Qatar': 'Asia',
    'Trinidad & Tobago': 'North America',
    'Northern Cyprus': 'Europe',
    'Hong Kong': 'Asia',
    'Bhutan': 'Asia',
    'Somalia': 'Africa',
    'Syria': 'Asia',
    'Belize': 'North America',
    'Sudan': 'Africa',
    'Angola': 'Africa',
    'Hong Kong S.A.R., China': 'Asia',
    'Puerto Rico': 'North America',
    'Suriname': 'South America',
    'Somaliland Region': 'Africa',
    'Oman': 'Asia',
    'Somaliland region': 'Africa',
    'Djibouti': 'Africa',
}

# %%
df['Kontinent'] = df['Country'].map(country_to_continent)

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2015, end=2024, step=1, value=2017)
year_slider
# Out:
# <pre>Traceback (most recent call last):
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\element.py&quot;, line 982, in _update_main_ranges
#     l, b, r, t = self.get_extents(element, ranges, dimension=range_dim)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 1994, in get_extents
#     xpad, ypad, zpad = self.get_padding(overlay, (x0, y0, z0, x1, y1, z1))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 1319, in get_padding
#     opts = self._traverse_options(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 916, in _traverse_options
#     return options if keyfn else options[None]
#                                  ~~~~~~~^^^^^^
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\pyviz_comms\__init__.py&quot;, line 340, in _handle_msg
#     self._on_msg(msg)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\viewable.py&quot;, line 471, in _on_msg
#     doc.unhold()
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\document.py&quot;, line 776, in unhold
#     self.callbacks.unhold()
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\callbacks.py&quot;, line 431, in unhold
#     self.trigger_on_change(event)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\callbacks.py&quot;, line 408, in trigger_on_change
#     invoke_with_curdoc(doc, event.callback_invoker)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\callbacks.py&quot;, line 443, in invoke_with_curdoc
#     return f()
#            ^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\bokeh\util\callback_manager.py&quot;, line 185, in invoke
#     callback(attr, old, new)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\reactive.py&quot;, line 469, in _comm_change
#     state._handle_exception(e)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\io\state.py&quot;, line 436, in _handle_exception
#     raise exception
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\reactive.py&quot;, line 467, in _comm_change
#     self._schedule_change(doc, comm)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\reactive.py&quot;, line 449, in _schedule_change
#     self._change_event(doc)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\reactive.py&quot;, line 445, in _change_event
#     self._process_events(events)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\panel\reactive.py&quot;, line 384, in _process_events
#     self.param.update(**self_events)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\param\parameterized.py&quot;, line 1902, in update
#     self_._batch_call_watchers()
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\param\parameterized.py&quot;, line 2063, in _batch_call_watchers
#     self_._execute_watcher(watcher, events)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\param\parameterized.py&quot;, line 2025, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\streams.py&quot;, line 760, in _watcher
#     self.trigger([self])
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\streams.py&quot;, line 186, in trigger
#     subscriber(**dict(union))
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 232, in refresh
#     raise e
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 228, in refresh
#     self._trigger_refresh(stream_key)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 245, in _trigger_refresh
#     self.update(key)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 944, in update
#     item = self.__getitem__(key)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 431, in __getitem__
#     self.update_frame(frame)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\element.py&quot;, line 2836, in update_frame
#     self._update_ranges(element, ranges)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\element.py&quot;, line 952, in _update_ranges
#     self._update_main_ranges(element, x_range, y_range, ranges)
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\bokeh\element.py&quot;, line 986, in _update_main_ranges
#     l, b, r, t = self.get_extents(element, ranges)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 1994, in get_extents
#     xpad, ypad, zpad = self.get_padding(overlay, (x0, y0, z0, x1, y1, z1))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 1319, in get_padding
#     opts = self._traverse_options(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File &quot;C:\ProgramData\anaconda3\Lib\site-packages\holoviews\plotting\plot.py&quot;, line 916, in _traverse_options
#     return options if keyfn else options[None]
#                                  ~~~~~~~^^^^^^
# KeyError: None
# </pre>
# IntSlider(end=2024, name='Year slider', start=2015, value=2017)

# %%
# Radio buttons for Happiness
yaxis_Happy = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness', 'Happiness_Rank',],
    button_type='success'
)

# %%
display(yaxis_Happy)
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Happiness', ...], value='Happiness')

# %%
continents = [ 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']#'World',

happy_pipeline = (
    idf[
        (idf.Year >= year_slider) &
        (idf.Kontinent.isin(continents))
    ]
    .groupby(['Kontinent', 'Year'])[yaxis_Happy].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happy_pipeline
# Out:
# <div id='9c9eecd5-12f2-463d-9ef1-cc9b3046407e'>
#   <div id="ad123522-9bbe-4ee5-ba5b-2fb8043cb8b0" data-root-id="9c9eecd5-12f2-463d-9ef1-cc9b3046407e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"01b5992b-31da-4c6a-8ea2-0412ab417e8b":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"9c9eecd5-12f2-463d-9ef1-cc9b3046407e","attributes":{"name":"Row01493","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"7f45609b-8c3e-43df-bc0a-d78e3120af99","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"db779b50-f66e-4800-a748-fee7db6170aa","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"de9724af-5746-46b5-8847-9dd640614888","attributes":{"name":"Column01490","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f45609b-8c3e-43df-bc0a-d78e3120af99"},{"id":"db779b50-f66e-4800-a748-fee7db6170aa"},{"id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7"},{"id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"05d2e3d7-3da7-45c9-8701-85d208521134","attributes":{"name":"Column01460","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f45609b-8c3e-43df-bc0a-d78e3120af99"},{"id":"db779b50-f66e-4800-a748-fee7db6170aa"},{"id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7"},{"id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"02ecc7e7-c877-4398-9f41-850738b392ed","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f45609b-8c3e-43df-bc0a-d78e3120af99"},{"id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7"},{"id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"db8f9290-bd30-4982-9d1a-a7cb5fcf6754","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f45609b-8c3e-43df-bc0a-d78e3120af99"},{"type":"object","name":"ImportedStyleSheet","id":"2d5f703f-a0a0-4a61-83d0-4533202100bf","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7"},{"id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d"}],"margin":[5,10],"align":"start","labels":["Happiness","Happiness_Rank"],"active":0}}]}},{"type":"object","name":"Column","id":"2d767b04-d972-4ff3-a9b2-08ab0d0e1b67","attributes":{"name":"Column01475","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f45609b-8c3e-43df-bc0a-d78e3120af99"},{"id":"db779b50-f66e-4800-a748-fee7db6170aa"},{"id":"abd41db5-fbc7-45f7-9685-1df3fddc4dc7"},{"id":"7c1b8519-1d28-41f7-9178-b57fbec3eb5d"}],"margin":0,"align":"start","children":[{"typ ...

# %%
happy_plot = happy_pipeline.hvplot(x = 'Year', by='Kontinent', y=yaxis_Happy,line_width=2, title="Happyness by Continent")

# %%
happy_plot
# Out:
# <div id='40cbbe4a-bf68-4103-8793-e8014b36d25f'>
#   <div id="bbb9dc63-4eb6-4c67-89b1-41d650536025" data-root-id="40cbbe4a-bf68-4103-8793-e8014b36d25f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4a50dec5-0b5f-4b5c-acd7-80e42322e8a5":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"40cbbe4a-bf68-4103-8793-e8014b36d25f","attributes":{"name":"Row01753","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"27a06ff6-6fed-4a51-a5bb-2703b7115bda","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5bbd063b-b764-43e3-a208-ed4ca7a85a3f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8423130d-f7bb-4dce-bec4-a636b1c05781","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3feabae5-0a6c-4afa-8786-04d1e9196cda","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"f40189c5-ea71-4156-9dff-6334c0e1d058","attributes":{"name":"Column01750","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"27a06ff6-6fed-4a51-a5bb-2703b7115bda"},{"id":"5bbd063b-b764-43e3-a208-ed4ca7a85a3f"},{"id":"8423130d-f7bb-4dce-bec4-a636b1c05781"},{"id":"3feabae5-0a6c-4afa-8786-04d1e9196cda"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"faf53dbe-d2fe-46a0-9fbc-9f002b5ce986","attributes":{"name":"Column01733","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"27a06ff6-6fed-4a51-a5bb-2703b7115bda"},{"id":"5bbd063b-b764-43e3-a208-ed4ca7a85a3f"},{"id":"8423130d-f7bb-4dce-bec4-a636b1c05781"},{"id":"3feabae5-0a6c-4afa-8786-04d1e9196cda"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"0caf1b56-700e-4de3-a5d3-69673b850a2e","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"27a06ff6-6fed-4a51-a5bb-2703b7115bda"},{"id":"8423130d-f7bb-4dce-bec4-a636b1c05781"},{"id":"3feabae5-0a6c-4afa-8786-04d1e9196cda"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"32aea35f-d7c3-4bab-ad44-bcb502a6fc34","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"27a06ff6-6fed-4a51-a5bb-2703b7115bda"},{"type":"object","name":"ImportedStyleSheet","id":"2d84ab2c-88b6-46b1-b61a-290f73647180","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"8423130d-f7bb-4dce-bec4-a636b1c05781"},{"id":"3feabae5-0a6c-4afa-8786-04d1e9196cda"}],"margin":[5,10],"align":"start","labels":["Happiness","Happiness_Rank"],"active":0}}]}},{"type":"object","name":"Figure","id":"0e18af62-e007-4529-bd9c-a349398874d1","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"885b3b91-208a-4e40-b529-8ce09e8705b6","attributes":{"tags":[[["Year","Year",null]],[]],"start":2017.0,"end":2023.0,"reset_start":2017.0,"reset_end":2023.0}},"y_range":{"type":"object","name":"Range1d","id":"9d46a7ab-ddf1-4166-95d0-f7c296e59d6d","attributes":{"tags":[[["Happiness","Happiness",null]],{"type":"map", ...

# %%
happy_table = happy_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')

# %%
happy_table
# Out:
# <div id='b27c7aae-fe9b-4586-b60b-6db01ec1f2d5'>
#   <div id="f26f2165-9209-4c67-a26f-76a55004d400" data-root-id="b27c7aae-fe9b-4586-b60b-6db01ec1f2d5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"da8e6c17-0f10-412a-9a5f-2c564a7cb554":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"b27c7aae-fe9b-4586-b60b-6db01ec1f2d5","attributes":{"name":"Row01950","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"84a1a514-1194-4a8c-abd4-9c42644ac199","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"27f0c1f6-2ff3-44b4-b378-95e8acaaac42","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"55d65ac0-c0d0-4608-8ed2-3140142cd70d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"Column","id":"2b960696-d7b8-41a1-931d-022c73e61805","attributes":{"name":"Column01947","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"84a1a514-1194-4a8c-abd4-9c42644ac199"},{"id":"27f0c1f6-2ff3-44b4-b378-95e8acaaac42"},{"id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc"},{"id":"55d65ac0-c0d0-4608-8ed2-3140142cd70d"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"Column","id":"5c1b8fcf-09dd-4751-90c6-a30e040fc290","attributes":{"name":"Column01929","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"84a1a514-1194-4a8c-abd4-9c42644ac199"},{"id":"27f0c1f6-2ff3-44b4-b378-95e8acaaac42"},{"id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc"},{"id":"55d65ac0-c0d0-4608-8ed2-3140142cd70d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"47d7746b-e4db-47c4-89db-3a8672a5ed2c","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"84a1a514-1194-4a8c-abd4-9c42644ac199"},{"id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc"},{"id":"55d65ac0-c0d0-4608-8ed2-3140142cd70d"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"643e2c46-83a1-446e-92c7-4b699b2c7d35","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"84a1a514-1194-4a8c-abd4-9c42644ac199"},{"type":"object","name":"ImportedStyleSheet","id":"e3dc6417-423b-43f7-b5a2-71e51eba7334","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc"},{"id":"55d65ac0-c0d0-4608-8ed2-3140142cd70d"}],"margin":[5,10],"align":"start","labels":["Happiness","Happiness_Rank"],"active":0}}]}},{"type":"object","name":"Column","id":"e152c1d9-1fa2-41e5-a18a-59923212e69e","attributes":{"name":"Column01944","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"84a1a514-1194-4a8c-abd4-9c42644ac199"},{"id":"27f0c1f6-2ff3-44b4-b378-95e8acaaac42"},{"id":"9ccb33f6-569a-4c26-962f-bd6730f23ebc"},{"id":"55d65ac0-c0d0-4608-8ed2- ...

# %%
happy_vs_GDP_scatterplot_pipeline = (
    idf[
        (idf.Year >= year_slider)
        #& (~ (idf.Kontinent.isin(continents)))
    ]
    .groupby(['Kontinent', 'Year', 'Explained_by_GDP'])['Happiness'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
#happy_vs_GDP_scatterplot_pipeline

# %%
happy_vs_GDP_scatterplot = happy_vs_GDP_scatterplot_pipeline.hvplot(x='Explained_by_GDP', 
                                                                y='Happiness', 
                                                                by='Kontinent', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=True, 
                                                                height=500, 
                                                                width=500)

# %%
happy_vs_GDP_scatterplot
# Out:
# <div id='0eaa18ac-0c0e-417e-b119-5c8617ab9954'>
#   <div id="ad331913-9b19-45d6-9801-439e453ac7ee" data-root-id="0eaa18ac-0c0e-417e-b119-5c8617ab9954" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b17a4d08-e0f1-4389-a9cf-3f1a4d885a77":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"0eaa18ac-0c0e-417e-b119-5c8617ab9954","attributes":{"name":"Row39979","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"ef033152-980e-44a9-b1ad-11769b434012","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"be5dbed5-ef3b-4f5f-852e-1552e0891e7a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4014af41-6dfd-4217-bbc1-f89ee922cd40","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"195abd39-61d3-43e4-baee-9190504e46a8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"0124e46f-9316-4adf-8f43-95c20b15e0b2","attributes":{"name":"Column39976","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ef033152-980e-44a9-b1ad-11769b434012"},{"id":"be5dbed5-ef3b-4f5f-852e-1552e0891e7a"},{"id":"4014af41-6dfd-4217-bbc1-f89ee922cd40"},{"id":"195abd39-61d3-43e4-baee-9190504e46a8"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"b3047984-4805-4699-ba02-cab256633c3c","attributes":{"name":"Column39959","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ef033152-980e-44a9-b1ad-11769b434012"},{"id":"be5dbed5-ef3b-4f5f-852e-1552e0891e7a"},{"id":"4014af41-6dfd-4217-bbc1-f89ee922cd40"},{"id":"195abd39-61d3-43e4-baee-9190504e46a8"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"cc2345d5-1937-4b55-a9f9-d2ac804b6616","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ef033152-980e-44a9-b1ad-11769b434012"},{"id":"4014af41-6dfd-4217-bbc1-f89ee922cd40"},{"type":"object","name":"ImportedStyleSheet","id":"0e96e1f5-a240-42b1-8e95-eb54b95d39e8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/fast.css"}}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2016}}]}},{"type":"object","name":"Figure","id":"e57602e4-ca72-49fe-8b97-e1dc39371add","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"627d0950-70aa-487f-ada9-80f664734eb5","attributes":{"tags":[[["Explained_by_GDP","Explained_by_GDP",null]],[]],"start":-0.22000000000000003,"end":2.4200000000000004,"reset_start":-0.22000000000000003,"reset_end":2.4200000000000004}},"y_range":{"type":"object","name":"Range1d","id":"f09b0156-a76c-4f62-8b9d-8e28e63de1ef","attributes":{"tags":[[["Happiness","Happiness",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":1.2607,"end":8.440299999999999,"reset_start":1.2607,"reset_end":8.440299999999999}},"x_scale":{"type":"object","name":"LinearScale","id":"254e9b07-d12d-4d3f-892b-9bd486c044be"},"y_scale":{"type":"object","name":"LinearScale","id":"4a80489c-335e-49f6-bec5-378d5fd968e1"},"title":{"type":"object","name":"Title","id":"9b21b065-3d17-4c35-8012-2e36a3046540","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRende ...

# %%
yaxis_happiness_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Explained_by_Trust', 'Explained_by_Freedom', 'Explained_by_GDP', 'Explained_by_Health', 'Explained_by_Social_support'], 
    button_type='success'
)

# %%
continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

# %%
happyness_source_bar_pipeline = (
    idf[
        (idf.Year == year_slider) &
        (idf.Kontinent.isin(continents_excl_world))
    ]
    .groupby(['Year', 'Kontinent'])[yaxis_happiness_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)

# %%
happyness_source_bar_plot =happyness_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='Kontinent', 
                                                     y=yaxis_happiness_source, 
                                                     title='Happyness source by continent')

# %%
happyness_source_bar_plot
# Out:
# <div id='4db25a74-b9c1-4eaf-b8cd-5d7656880f75'>
#   <div id="eb79241b-50c8-4e88-b582-71f027a15b5b" data-root-id="4db25a74-b9c1-4eaf-b8cd-5d7656880f75" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"17640557-35d9-4fa5-9995-f382bf59e3b4":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"4db25a74-b9c1-4eaf-b8cd-5d7656880f75","attributes":{"name":"Row03607","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"88adc622-0c36-4ce4-b828-61b0a32bd7ba","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b012e14d-a96d-4068-aa59-3f66f40bd498","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cd43127e-6594-42e0-927c-112d1cb80ef2","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c4360ad4-709a-41ed-a481-517bc75aae7e","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"49e9e67d-2d87-4d0d-9960-7007ffa18d6a","attributes":{"name":"Column03604","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88adc622-0c36-4ce4-b828-61b0a32bd7ba"},{"id":"b012e14d-a96d-4068-aa59-3f66f40bd498"},{"id":"cd43127e-6594-42e0-927c-112d1cb80ef2"},{"id":"c4360ad4-709a-41ed-a481-517bc75aae7e"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"f3df4dee-1c38-4353-89e2-003e1d53eb2c","attributes":{"name":"Column03587","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88adc622-0c36-4ce4-b828-61b0a32bd7ba"},{"id":"b012e14d-a96d-4068-aa59-3f66f40bd498"},{"id":"cd43127e-6594-42e0-927c-112d1cb80ef2"},{"id":"c4360ad4-709a-41ed-a481-517bc75aae7e"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"0be54c25-be57-4fec-bd2c-86b1601eacf6","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88adc622-0c36-4ce4-b828-61b0a32bd7ba"},{"id":"cd43127e-6594-42e0-927c-112d1cb80ef2"},{"id":"c4360ad4-709a-41ed-a481-517bc75aae7e"}],"margin":[5,10],"align":"start","title":"Year slider","start":2015,"end":2024,"value":2017}},{"type":"object","name":"RadioButtonGroup","id":"92ebbe82-f7cc-4502-818f-5bd09b25437e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"88adc622-0c36-4ce4-b828-61b0a32bd7ba"},{"type":"object","name":"ImportedStyleSheet","id":"0f7886d7-e290-4611-b848-e0ecfb32e5b4","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"cd43127e-6594-42e0-927c-112d1cb80ef2"},{"id":"c4360ad4-709a-41ed-a481-517bc75aae7e"}],"margin":[5,10],"align":"start","labels":["Explained_by_Trust","Explained_by_Freedom","Explained_by_GDP","Explained_by_Health","Explained_by_Social_support"],"active":0}}]}},{"type":"object","name":"Figure","id":"a756ea2e-f3d0-4981-a1ac-13920f416941","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"d7403a9f-2387-463e-8a5e-421b17bba1e0","attributes":{"tags":[[["Kontinent","Kontinent",null]],[]],"factors":["Africa","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","i ...

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World Happyness dashboard', 
    sidebar=[pn.pane.Markdown("# Happyness"), 
             pn.pane.Markdown("####GDP is the biggest contributor to happyness."), 
             pn.pane.PNG('happy.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_Happy, 
                           happy_plot.panel(width=700), margin=(0,25)), 
                 happy_table.panel(width=500)), 
          pn.Row(pn.Column(happyness_source_bar_plot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_happiness_source, happyness_source_bar_pipeline.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

# %%
template.show()
# Out:
# Launching server at http://localhost:52506

# %%
template.servable();
